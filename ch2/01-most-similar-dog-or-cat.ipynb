# %% [markdown]
# ## 나는 개와 고양이 중 누구와 더 닮았을까?

# %% [markdown]
# ---
# ### 우선 유사도 측정 샘플 코드 부터

# %%
## distance 함수 sample
from __future__ import print_function
from scipy.spatial import distance

u = [20, 30, 90]
v = [3,23,40]

print ( 'euclidean distance  ' , distance.euclidean(u,v))
print ( 'cosine distance     ' , distance.cosine(u,v))
print ( 'jaccard distance    ' , distance.jaccard([1,1,0,0],[0,1,1,0]))
print ( 'correlation distance' , distance.correlation(u,v))
# Out:
# euclidean distance   53.2728824075
# cosine distance      0.0296654847361
# jaccard distance     0.666666666667
# correlation distance 0.094365278326

# %% [markdown]
# ---
# ### Facial keypoint 데이터 저장
# * http://www.faceplusplus.com/demo-landmark/ 접속
# * 83 point로 나의 facial point를 추출한다.
# * 결과 json 파일을 카피하여 변수에 담는다.

# %%
#facial information list
fi_list = {}

# %%
# 최규민 facial point 
# https://fbcdn-sphotos-g-a.akamaihd.net/hphotos-ak-xta1/v/t1.0-9/12122398_906503296086905_9053689686321602818_n.jpg?oh=80fcaf06feebc607119139261daa82ee&oe=5696C59E&__gda__=1452163095_656cdb05f7f03f0920879b17b79041be 
fi_list['me'] = '''
{
  "result": [
    {
      "face_id": "3934ba2c75cd522702b7c0cb880cf04c",
      "landmark": {
        "contour_chin": {
          "x": 46.870333,
          "y": 39.516444
        },
        "contour_left1": {
          "x": 39.563,
          "y": 24.433778
        },
        "contour_left2": {
          "x": 39.6425,
          "y": 26.722
        },
        "contour_left3": {
          "x": 39.836667,
          "y": 28.721333
        },
        "contour_left4": {
          "x": 40.219,
          "y": 30.990889
        },
        "contour_left5": {
          "x": 40.659333,
          "y": 32.897778
        },
        "contour_left6": {
          "x": 41.447333,
          "y": 34.854222
        },
        "contour_left7": {
          "x": 42.452333,
          "y": 36.781556
        },
        "contour_left8": {
          "x": 43.545833,
          "y": 38.136667
        },
        "contour_left9": {
          "x": 45.202167,
          "y": 39.372444
        },
        "contour_right1": {
          "x": 54.509167,
          "y": 22.996222
        },
        "contour_right2": {
          "x": 54.733833,
          "y": 25.442667
        },
        "contour_right3": {
          "x": 54.652167,
          "y": 27.907778
        },
        "contour_right4": {
          "x": 54.464167,
          "y": 30.252222
        },
        "contour_right5": {
          "x": 53.924167,
          "y": 32.507333
        },
        "contour_right6": {
          "x": 53.326167,
          "y": 34.674667
        },
        "contour_right7": {
          "x": 52.0905,
          "y": 36.589111
        },
        "contour_right8": {
          "x": 50.638167,
          "y": 37.974889
        },
        "contour_right9": {
          "x": 48.954,
          "y": 39.166667
        },
        "left_eye_bottom": {
          "x": 42.709833,
          "y": 24.540444
        },
        "left_eye_center": {
          "x": 42.621167,
          "y": 24.078667
        },
        "left_eye_left_corner": {
          "x": 41.411333,
          "y": 24.381333
        },
        "left_eye_lower_left_quarter": {
          "x": 41.884,
          "y": 24.394667
        },
        "left_eye_lower_right_quarter": {
          "x": 43.3445,
          "y": 24.346889
        },
        "left_eye_pupil": {
          "x": 47.476167,
          "y": 27.186444
        },
        "nose_contour_right3": {
          "x": 47.342,
          "y": 29.806889
        },
        "nose_left": {
          "x": 43.8845,
          "y": 29.219778
        },
        "nose_right": {
          "x": 48.420833,
          "y": 28.996889
        },
        "nose_tip": {
          "x": 45.8285,
          "y": 28.680889
        },
        "right_eye_bottom": {
          "x": 49.710667,
          "y": 23.790889
        },
        "right_eye_center": {
          "x": 49.723,
          "y": 23.424667
        },
        "right_eye_left_corner": {
          "x": 48.332167,
          "y": 23.825333
        },
        "right_eye_lower_left_quarter": {
          "x": 49.029833,
          "y": 23.787111
        },
        "right_eye_lower_right_quarter": {
          "x": 50.623167,
          "y": 23.605556
        },
        "right_eye_pupil": {
          "x": 49.837333,
          "y": 23.349111
        },
        "right_eye_right_corner": {
          "x": 51.333333,
          "y": 23.384
        },
        "right_eye_top": {
          "x": 49.611167,
          "y": 23.050889
        },
        "right_eye_upper_left_quarter": {
          "x": 48.975333,
          "y": 23.216667
        },
        "right_eye_upper_right_quarter": {
          "x": 50.388,
          "y": 23.096444
        },
        "right_eyebrow_left_corner": {
          "x": 47.5245,
          "y": 21.065533
        },
        "right_eyebrow_lower_left_quarter": {
          "x": 48.645,
          "y": 20.969889
        },
        "right_eyebrow_lower_middle": {
          "x": 49.7605,
          "y": 20.727756
        },
        "right_eyebrow_lower_right_quarter": {
          "x": 51.063333,
          "y": 20.718178
        },
        "right_eyebrow_right_corner": {
          "x": 52.138167,
          "y": 21.139978
        },
        "right_eyebrow_upper_left_quarter": {
          "x": 48.576667,
          "y": 20.0346
        },
        "right_eyebrow_upper_middle": {
          "x": 49.652333,
          "y": 19.742422
        },
        "right_eyebrow_upper_right_quarter": {
          "x": 51.110833,
          "y": 20.070533
        }
      }
    }
  ],
  "session_id": "8c182556e6514153ab40239315487b44"
}
'''

# %%
fi_list
# Out:
# {'me': '\n{\n  "result": [\n    {\n      "face_id": "3934ba2c75cd522702b7c0cb880cf04c",\n      "landmark": {\n        "contour_chin": {\n          "x": 46.870333,\n          "y": 39.516444\n        },\n        "contour_left1": {\n          "x": 39.563,\n          "y": 24.433778\n        },\n        "contour_left2": {\n          "x": 39.6425,\n          "y": 26.722\n        },\n        "contour_left3": {\n          "x": 39.836667,\n          "y": 28.721333\n        },\n        "contour_left4": {\n          "x": 40.219,\n          "y": 30.990889\n        },\n        "contour_left5": {\n          "x": 40.659333,\n          "y": 32.897778\n        },\n        "contour_left6": {\n          "x": 41.447333,\n          "y": 34.854222\n        },\n        "contour_left7": {\n          "x": 42.452333,\n          "y": 36.781556\n        },\n        "contour_left8": {\n          "x": 43.545833,\n          "y": 38.136667\n        },\n        "contour_left9": {\n          "x": 45.202167,\n        
# ...

# %%
# dog facial data
# image url : http://cfs8.blog.daum.net/image/14/blog/2008/09/01/10/44/48bb48f38ab38
fi_list['dog'] = '''
{
  "result": [
    {
      "face_id": "8dca048fcd1b2aa2a25f001daa73ca89",
      "landmark": {
          "y": 40.666098
        },
        "nose_contour_lower_middle": {
          "x": 50.332439,
          "y": 40.921463
        },
        "nose_contour_right1": {
          "x": 51.781463,
          "y": 31.481707
        },
        "nose_contour_right2": {
          "x": 52.961951,
          "y": 36.989512
        },
        "nose_contour_right3": {
          "x": 52.010732,
          "y": 40.470244
        },
        "nose_left": {
          "x": 46.931951,
          "y": 39.471707
        },
        "nose_right": {
          "x": 53.499512,
          "y": 39.457805
        },
        "nose_tip": {
          "x": 50.144634,
          "y": 38.63
        },
        "right_eye_bottom": {
          "x": 57.076341,
          "y": 32.073171
        },
        "right_eye_center": {
          "x": 56.862195,
          "y": 30.826098
        },
        "right_eye_left_corner": {
          "x": 53.539268,
          "y": 31.576098
        },
        "right_eye_lower_left_quarter": {
          "x": 55.183171,
          "y": 31.87
        },
        "right_eye_lower_right_quarter": {
          "x": 58.567805,
          "y": 31.557561
        },
        "right_eye_pupil": {
          "x": 56.519756,
          "y": 30.601951
        },
        "right_eye_right_corner": {
          "x": 59.69122,
          "y": 30.945122
        },
        "right_eye_top": {
          "x": 56.864634,
          "y": 29.512927
        },
        "right_eye_upper_left_quarter": {
          "x": 55.061707,
          "y": 29.996829
        },
        "right_eye_upper_right_quarter": {
          "x": 58.419756,
          "y": 29.945366
        },
        "right_eyebrow_left_corner": {
          "x": 53.404146,
          "y": 27.398049
        },
        "right_eyebrow_lower_left_quarter": {
          "x": 55.658293,
          "y": 27.422439
        },
        "right_eyebrow_lower_middle": {
          "x": 57.982683,
          "y": 27.271951
        },
        "right_eyebrow_lower_right_quarter": {
          "x": 60.402683,
          "y": 27.228537
        },
        "right_eyebrow_right_corner": {
          "x": 62.01878,
          "y": 27.734634
        },
        "right_eyebrow_upper_left_quarter": {
          "x": 55.66,
          "y": 25.990732
        },
        "right_eyebrow_upper_middle": {
          "x": 57.970488,
          "y": 25.775366
        },
        "right_eyebrow_upper_right_quarter": {
          "x": 60.472195,
          "y": 26.064878
        }
      }
    }
  ],
  "session_id": "1d65b781c5914b9fb2e1029bf59e2f37"
}
'''

# %% [markdown]
# ### facial keypoint 에서 특징점에 관련 정보로 변환 및 추출

# %%
import json
import numpy as np

def pos_distance(l,r):
#    print(l,r)
    return round(distance.euclidean( [l['x'], l['y']], [r['x'], r['y']] ),5)

def pos_center(l,r):
    return {'x':(l['x']+r['x'])/2, 'y':(l['y']+r['y'])/2}

def extract_face_feature(facial_info):
    cal_items = {'face_width'    :['contour_left9', 'contour_right9']
                 ,'face_height'  :['eyebrow_center','contour_chin']
                 ,'mouth_width'  :['mouth_left_corner','mouth_right_corner']  
                 ,'nose_width'   :['nose_left','nose_right']  
                 ,'eye_width'    :['left_eye_left_corner','right_eye_right_corner']  
                 ,'eye_to_eye'   :['left_eye_center','right_eye_center']  
                 ,'eyebrow_width':['left_eyebrow_upper_middle','left_eyebrow_lower_middle']  
                 ,'lip_to_chin'  :['mouth_lower_lip_bottom','contour_chin']  
                 ,'lip_to_nose'  :['nose_tip','mouth_upper_lip_top']}
    
    keypoint = {}
    
    ## json string to object
    info = None
    if type(facial_info) == str:
        info = json.loads(facial_info)
    
    facial_pos = info['result'][0]['landmark']
    ## add center position
    facial_pos['eyebrow_center'] = pos_center( facial_pos['left_eyebrow_upper_middle']
                                              , facial_pos['right_eyebrow_upper_middle']) 
    
    ## calculate key point
    for (k,v) in cal_items.items(): ## iteritems() for python2.7
        keypoint[k] = pos_distance(facial_pos[v[0]], facial_pos[v[1]])
        
    return keypoint

def normalize_dict(data, max_value):
    for k in data.keys():
        data[k] = round(data[k]/max_value,5)
    return data

def get_feature_vector( keypoint ):
    ff = extract_face_feature(keypoint)
    ff = normalize_dict(ff, ff['face_height'])
    return ff

# %%
extract_face_feature(fi_list['me'])
# Out:
# {'eye_to_eye': 7.13188,
#  'eye_width': 9.972,
#  'eyebrow_width': 0.84281,
#  'face_height': 19.43574,
#  'face_width': 3.75747,
#  'lip_to_chin': 4.73426,
#  'lip_to_nose': 3.39551,
#  'mouth_width': 6.46129,
#  'nose_width': 4.54181}

# %%
V = extract_face_feature(fi_list['me'])
normalize_dict(V , V['face_width'])
# Out:
# {'eye_to_eye': 1.89805,
#  'eye_width': 2.65391,
#  'eyebrow_width': 0.2243,
#  'face_height': 5.17256,
#  'face_width': 1.0,
#  'lip_to_chin': 1.25996,
#  'lip_to_nose': 0.90367,
#  'mouth_width': 1.71959,
#  'nose_width': 1.20874}

# %%
for name, fi in fi_list.items():
    print(name, get_feature_vector(fi))
# Out:
# me {'eye_to_eye': 0.36695, 'eye_width': 0.51308, 'lip_to_chin': 0.24359, 'face_width': 0.19333, 'eyebrow_width': 0.04336, 'face_height': 1.0, 'nose_width': 0.23368, 'mouth_width': 0.33244, 'lip_to_nose': 0.1747}
# girl {'eye_to_eye': 0.48434, 'eye_width': 0.6978, 'lip_to_chin': 0.17931, 'face_width': 0.24306, 'eyebrow_width': 0.05167, 'face_height': 1.0, 'nose_width': 0.23755, 'mouth_width': 0.31194, 'lip_to_nose': 0.18145}
# dog {'eye_to_eye': 0.37389, 'eye_width': 0.53028, 'lip_to_chin': 0.22158, 'face_width': 0.19849, 'eyebrow_width': 0.03709, 'face_height': 1.0, 'nose_width': 0.22743, 'mouth_width': 0.3132, 'lip_to_nose': 0.22118}
# cat {'eye_to_eye': 0.35113, 'eye_width': 0.49442, 'lip_to_chin': 0.28737, 'face_width': 0.20738, 'eyebrow_width': 0.0376, 'face_height': 1.0, 'nose_width': 0.17405, 'mouth_width': 0.22737, 'lip_to_nose': 0.195}

# %% [markdown]
# ### 나, 개, 고양이 간에 유사도 측정

# %%
## extract vector
import pandas as pd
features = {}
for (name, info) in fi_list.items():
    ff = extract_face_feature(fi_list[name])
    ff = normalize_dict(ff, ff['face_height'])
    features[name] = ff.values()
features
# Out:
# {'cat': [0.35113,
#   0.49442,
#   0.28737,
#   0.20738,
#   0.0376,
#   1.0,
#   0.17405,
#   0.22737,
#   0.195],
#  'dog': [0.37389,
#   0.53028,
#   0.22158,
#   0.19849,
#   0.03709,
#   1.0,
#   0.22743,
#   0.3132,
#   0.22118],
#  'girl': [0.48434,
#   0.6978,
#   0.17931,
#   0.24306,
#   0.05167,
#   1.0,
#   0.23755,
#   0.31194,
#   0.18145],
#  'me': [0.36695,
#   0.51308,
#   0.24359,
#   0.19333,
#   0.04336,
#   1.0,
#   0.23368,
#   0.33244,
#   0.1747]}

# %%
## dict to dataframe
features_ds = pd.DataFrame.from_dict(features, orient='index')
features_ds
# Out:
#             0        1        2        3        4  5        6        7  \
# me    0.36695  0.51308  0.24359  0.19333  0.04336  1  0.23368  0.33244
# girl  0.48434  0.69780  0.17931  0.24306  0.05167  1  0.23755  0.31194
# dog   0.37389  0.53028  0.22158  0.19849  0.03709  1  0.22743  0.31320
# cat   0.35113  0.49442  0.28737  0.20738  0.03760  1  0.17405  0.22737
#
#             8
# me    0.17470
# girl  0.18145
# dog   0.22118
# cat   0.19500

# %%
print (distance.euclidean( features_ds.loc['me'] , features_ds.loc['cat']))
print (distance.euclidean( features_ds.loc['me'] , features_ds.loc['dog']))
# Out:
# 0.133241391092
# 0.058855863769

# %%
def distanceMeasure( a, b, distancefunc=distance.euclidean):
    dist = distancefunc( features_ds.loc[a], features_ds.loc[b])
    print( "{0}-{1} distance : {2}".format(a,b,dist))

# %% [markdown]
# ### 개-고양이-나 와 유사도 측정

# %%
distanceMeasure('me','cat',distance.euclidean)
distanceMeasure('me','dog',distance.euclidean)
# Out:
# me-cat distance : 0.133241391092
# me-dog distance : 0.058855863769

# %%
distanceMeasure('me','cat',distance.cosine)
distanceMeasure('me','dog',distance.cosine)
# Out:
# me-cat distance : 0.0050961549365
# me-dog distance : 0.00100514305399

# %%
distanceMeasure('me','cat',distance.correlation)
distanceMeasure('me','dog',distance.correlation)
# Out:
# me-cat distance : 0.0126971819181
# me-dog distance : 0.00272784227326

# %% [markdown]
# ### 나는 개상이네요 ~~

# %%
distanceMeasure('dog','cat',distance.euclidean)
distanceMeasure('me','cat',distance.euclidean)
distanceMeasure('me','dog',distance.euclidean)
# Out:
# dog-cat distance : 0.130817350531
# me-cat distance : 0.133241391092
# me-dog distance : 0.058855863769

# %%
distanceMeasure('dog','cat',distance.cosine)
distanceMeasure('me','cat',distance.cosine)
distanceMeasure('me','dog',distance.cosine)
# Out:
# dog-cat distance : 0.0047427032299
# me-cat distance : 0.0050961549365
# me-dog distance : 0.00100514305399

# %%
distanceMeasure('girl','me',distance.cosine)
distanceMeasure('girl','cat',distance.cosine)
distanceMeasure('girl','dog',distance.cosine)
# Out:
# girl-me distance : 0.0114182341805
# girl-cat distance : 0.0174711418028
# girl-dog distance : 0.0092941627035

# %%
#import urllib.parse
#import urllib.request
import json
import requests

## face detect api call 
def face_detect(imgurl):
    url = 'http://apius.faceplusplus.com/v2/detection/detect'
    headers = { 'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36',
               'Origin':'http://www.faceplusplus.com', 
               'Accept-Language':'ko-KR,ko;q=0.8,en-US;q=0.6,en;q=0.4', 
               'Content-type':'application/x-www-form-urlencoded', 
               'Accept':'*/*', 
               'Referer':'http://www.faceplusplus.com/demo-landmark/', 
               'Connection':'keep-alive'
              }
    values = {'attribute' : 'none',
              'url' : imgurl,
              'api_key' : 'e6f2c06ac2b93b1ae6aad80b90d49eb0',
              'api_secret' : '8o_amgigF4dV4EHZ2OOVEejDeXq4qFab'}
  
    response = requests.post(url,params=values,headers=headers)
    response_data = response.text
    return json.loads(response_data.decode('utf-8'))

## face landmark api call by face_id
def face_landmark(faceid):
    url = 'http://apius.faceplusplus.com/v2/detection/landmark'
    headers = { 'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36',
               'Origin':'http://www.faceplusplus.com', 
               'Accept-Language':'ko-KR,ko;q=0.8,en-US;q=0.6,en;q=0.4', 
               'Content-type':'application/x-www-form-urlencoded', 
               'Accept':'*/*', 
               'Referer':'http://www.faceplusplus.com/demo-landmark/', 
               'Connection':'keep-alive'
              }
    values = {'face_id' : faceid,
              'type' : '83p',
              'api_key' : 'e6f2c06ac2b93b1ae6aad80b90d49eb0',
              'api_secret' : '8o_amgigF4dV4EHZ2OOVEejDeXq4qFab'}
    
    response = requests.post(url,params=values,headers=headers)
    response_data = response.text
    return json.loads(response_data.decode('utf-8'))

def extract_face_landmark( imgurl, face_index=0 ) :
    fd = face_detect(imgurl)
    face_id = fd['face'][face_index]['face_id']
    return face_landmark(face_id)

# %%
#extract_face_randmark('https://fbcdn-sphotos-g-a.akamaihd.net/hphotos-ak-xta1/v/t1.0-9/12122398_906503296086905_9053689686321602818_n.jpg?oh=80fcaf06feebc607119139261daa82ee&oe=5696C59E&__gda__=1452163095_656cdb05f7f03f0920879b17b79041be' )
extract_face_landmark('http://historie.kr/img/face_x/goodvc_02.jpg')
#face_landmark('9365ac5dda4ffcadebb0fc47f962ba9a')
# Out:
# {u'result': [{u'face_id': u'07470e8415ea64f75c6fdabd9713a932',
#    u'landmark': {u'contour_chin': {u'x': 48.757833, u'y': 90.29975},
#     u'contour_left1': {u'x': 34.813333, u'y': 52.247},
#     u'contour_left2': {u'x': 34.997667, u'y': 56.2115},
#     u'contour_left3': {u'x': 35.400667, u'y': 60.84475},
#     u'contour_left4': {u'x': 36.105833, u'y': 66.36075},
#     u'contour_left5': {u'x': 36.743667, u'y': 71.34},
#     u'contour_left6': {u'x': 38.005, u'y': 76.25775},
#     u'contour_left7': {u'x': 39.488167, u'y': 81.53075},
#     u'contour_left8': {u'x': 41.328, u'y': 85.589},
#     u'contour_left9': {u'x': 44.5275, u'y': 89.0005},
#     u'contour_right1': {u'x': 64.789833, u'y': 51.99675},
#     u'contour_right2': {u'x': 64.5915, u'y': 57.55675},
#     u'contour_right3': {u'x': 64.300667, u'y': 63.4905},
#     u'contour_right4': {u'x': 63.458167, u'y': 68.55775},
#     u'contour_right5': {u'x': 62.393333, u'y': 73.56725},
# ...
