# %%
# coding: utf-8
from __future__ import print_function
import pandas as pd
import numpy as np
from matplotlib import rcParams
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import networkx as nx
from datetime import datetime
import gensim, logging
import matplotlib.patches as mpatches
import matplotlib
import time

# %matplotlib inline  

rcParams['font.family'] = 'NanumGothic'
rcParams.update({'font.size': 12})
matplotlib.style.use('ggplot')
sns.set_style("whitegrid")

# %% [markdown]
# ## 무비 렌즈 데이터로 별점을 예측해 보자
# * User Based 별점 예측
# * Item(Movie) Based 별점 예측

# %% [markdown]
# Movie Lens 데이터 로드
# http://grouplens.org/datasets/movielens/

# %%
def movieLensDataLoad(type):
    ## user 영화 별점 data 
    ratings = pd.read_csv("/Users/goodvc/Documents/data-analytics/movie-recommendation/"+type+"/ratings.csv")

    ## movie meta(타이트,장르) data 
    movies = pd.read_csv("/Users/goodvc/Documents/data-analytics/movie-recommendation/"+type+"/movies.csv")

    ## user가 영화에 tag를 기입한 data
    tags = pd.read_csv("/Users/goodvc/Documents/data-analytics/movie-recommendation/"+type+"/tags.csv")
    # tags = pd.read_csv("/Users/goodvc/Documents/data-analytics/movie-recommendation/ml-20m/tags.csv")
    return ( ratings, movies, tags )

#ratings, movies, tags = movieLensDataLoad('ml-20m')
ratings, movies, tags = movieLensDataLoad('ml-latest-small')

# %%
#ratings = pd.read_csv("movieLens/ml-latest-small/ratings.csv")
ratings.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        6       2  980730861
# 1       1       22       3  980731380
# 2       1       32       2  980731926
# 3       1       50       5  980732037
# 4       1      110       4  980730408
# 5       1      164       3  980731766
# 6       1      198       3  980731282
# 7       1      260       5  980730769
# 8       1      296       4  980731208
# 9       1      303       3  980732235

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
tags.head(10)
# Out:
#    userId  movieId               tag   timestamp
# 0      40        1         animation  1306926135
# 1      40        1           fantasy  1306926130
# 2      40        1             Pixar  1306926133
# 3      40       47              dark  1306930201
# 4      40       47        disturbing  1306930291
# 5      40       47          thriller  1306930308
# 6      40      101   off-beat comedy  1307009664
# 7      40      101      Wes Anderson  1307009667
# 8      40      208  post-apocalyptic  1306930611
# 9      40      208            sci-fi  1306930614

# %%
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100023.000000  100023.000000  100023.000000  1.000230e+05
# mean      341.760765    8613.123442       3.491362  1.091520e+09
# std       193.849755   19736.006106       1.067942  1.633577e+08
# min         1.000000       1.000000       0.500000  8.285049e+08
# 25%       180.000000     783.000000       3.000000  9.606706e+08
# 50%       343.000000    2081.000000       3.500000  1.097974e+09
# 75%       511.000000    4367.000000       4.000000  1.205150e+09
# max       706.000000  129651.000000       5.000000  1.427755e+09

# %% [markdown]
# ### User Based 별점 예측
#
# U(User)
# M(Movie)
#
# 1. U X M vector Matrix를 만든다.
#  key가 userid, value가 { 'movieId':rating }
# 2. 나와 비슷한 유저를 찾는다.

# %%
## 1. U X M vector Matrix를 만든다. 
UM_matrix_ds = ratings.pivot(index='userId', columns='movieId', values='rating')

# %%
UM_matrix_ds.head()
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           NaN     NaN     NaN     NaN     NaN       2     NaN     NaN
# 2           NaN       4     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN       4     NaN       4     NaN       4     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  9       10       ...    121271  122284  122495  122756  123109  \
# userId                    ...
# 1           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
#
# movieId  124857  125916  126407  129454  129651
# userId
# 1           NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 8552 columns]

# %%
## 그럼 이제 최근접 이웃을 찾차 보자
## 
import math
from operator import itemgetter
from scipy.spatial import distance

def distance_cosine(a,b):
    return 1-distance.cosine(a,b)

def disance_corr(a,b):
    return 1-distance.correlation (a,b)

def distance_euclidean(a,b):
    return 1/(distance.euclidean(a,b)+1)

# %%
def nearest_neighbor_user( user, topN, simFunc ) :  
    u1 = UM_matrix_ds.loc[user].dropna()
    ratedIndex = u1.index
    nn = {}
    
    ## Brote Force Compute
    for uid, row in UM_matrix_ds.iterrows():
        interSectionU1 = []
        interSectionU2 = []
        if uid==user:
            continue
        for i in ratedIndex:
            if False==math.isnan(row[i]):
                interSectionU1.append(u1[i])
                interSectionU2.append(row[i])
        interSectionLen = len(interSectionU1)
        
       
    ## At least 3 intersection items
        if interSectionLen < 3 :
            continue
            
        ## similarity functon
        sim = simFunc(interSectionU1,interSectionU2)
        
        if  math.isnan(sim) == False:
            nn[uid] = sim
            
    ## top N returned         
    return sorted(nn.items(),key=itemgetter(1))[:-(topN+1):-1]

# %%
st=time.time()
(nearest_neighbor_user(8,50,distance_euclidean))
print(time.time()-st, 'sec')
# Out:
# 0.778939008713 sec

# %%
## 클러스터링 된 결과와 그냥 했을때의 성능 비교
## 결과 비교

# %%
from sklearn.cluster import KMeans

class UserKmeansCluster:
    def __init__(self, matrix_ds):
        self.result = 0
        self.matrix_ds = matrix_ds
        self.user_size = matrix_ds.index.size
        
    def clustering(self):
        ## cluster k 결정 
        self.K = int(math.ceil(math.sqrt( UM_matrix_ds.index.size / 2)))
        
        ## clustering by kmeans
        X = self.matrix_ds.fillna(0).values
        self.cluster = KMeans(n_clusters=self.K)
        self.cluster.fit(X)
        
        ## cluster result 
        self.cluster_members = defaultdict(list)
        self.user2cid = defaultdict(int)
        for user, cid in zip(self.matrix_ds.index, self.cluster.labels_):
            self.cluster_members[cid].append(user)
            self.user2cid[user] = cid
        
    def user2cluster(self, user):
        return self.user2cid.get(user,-1)

    def get_members(self, cid):
        return self.cluster_members.get(cid,[])

    def user2members(self, user):
        cid = self.user2cluster(user)
        return self.get_members(cid)

        
usercluster = UserKmeansCluster(UM_matrix_ds[:1000])
usercluster.clustering()

# %%
## graph cut

# %%
def graph_cut( ds, threshold=3 ):
    grouped = ds.groupby('movieId')
    userlink = defaultdict(int)
    for name, g in grouped:
        users = g['userId'].values
        cnt = users.size
        if cnt<2:
            continue

        for n in range(0,cnt):
            for m in range(n+1,cnt):
                key = "{0}:{1}" if users[n]<users[m] else "{1}:{0}"
                key = key.format(users[n], users[m])
                userlink[key] = userlink[key] + 1
                
    neighbors = defaultdict(list)
    n=0
    for k, v in userlink.items():
        if (v) > threshold:
            nm = k.split(':')
            if len(nm) == 2:
                neighbors[nm[0]].append(nm[1])
                neighbors[nm[1]].append(nm[0])
                n = n+1
                
    print("user link수 : ", n)
    return neighbors

neighbors = graph_cut(ratings)
# Out:
# user link수 :  152655

# %%
## 평균 neightbor
total = 0
cnt = 0
for k,v in neighbors.items():
    cnt = cnt + 1
    total = total + len(v)

# %%
def predictRating(userid, nn=100, simFunc=distance_cosine) :
   
    ## neighboorhood 
    neighbor = nearest_neighbor_user(userid,nn,simFunc)
    neighbor_id = [id for id,sim in neighbor]
    
    ## neighboorhood's movie : al least 4 ratings
    neighbor_movie = UM_matrix_ds.loc[neighbor_id]\
                    .dropna(1, how='all', thresh = 4 )
    neighbor_dic = (dict(neighbor))
    ret = [] # ['movieId', 'predictedRate']
    
    ## rating predict by my similarities 
    for movieId, row in neighbor_movie.iteritems():
        jsum, wsum = 0, 0
        for v in row.dropna().iteritems():
            sim = neighbor_dic.get(v[0],0)
            jsum += sim
            wsum += (v[1]*sim)
        ret.append([movieId, wsum/jsum])
       
    return ret

# %%
def ratingMovies(userid):
    return pd.merge(ratings[ratings.userId==userid], movies, on=['movieId'])

# %%
import time
gtime=time.time()
def elapse(string=""):
    global gtime
    now = time.time()
    if string!="":
        print ("{1} : {0} sec".format(now - gtime, string))
    gtime = now

# %%
userid=12
pd.options.display.max_rows=14
ratingMovies(userid).sort(['rating'],ascending=False)[['rating','title','genres']].head(100)
# Out:
#     rating                                          title  \
# 2        5                                 Vertigo (1958)
# 1        5               Silence of the Lambs, The (1991)
# 13       4        Importance of Being Earnest, The (2002)
# 15       4                    Bourne Identity, The (2002)
# 3        4         One Flew Over the Cuckoo's Nest (1975)
# 24       4                     Last Seduction, The (1994)
# 20       4             Austin Powers in Goldmember (2002)
# ..     ...                                            ...
# 11       2                              Unfaithful (2002)
# 18       2                        Lovely & Amazing (2001)
# 22       2                              Blood Work (2002)
# 5        2                                   Glory (1989)
# 25       2                             Miami Blues (1990)
# 14       1  Divine Secrets of the Ya-Ya Sisterhood (2002)
# 7        1               Karate Kid, Part III, The (1989)
#
#                              genres
# 2    Drama|Mystery|Romance|Thriller
# 1             Crime|Horror|Thriller
# 13             Comedy|Drama|Romance
# 15          Action|Mystery|Thriller
# 3                             Drama
# 24             Crime|Drama|Thriller
# 20                           Comedy
# ..                              ...
# 11                   Drama|Thriller
# 18             Comedy|Drama|Romance
# 22     Crime|Drama|Mystery|Thriller
# 5                         Drama|War
# 25               Comedy|Crime|Drama
# 14                     Comedy|Drama
# 7   Action|Adventure|Children|Drama
#
# [26 rows x 3 columns]

# %%
userid=1
predicted_ratings = pd.DataFrame(predictRating(userid),columns=['movieId', 'predicted_rating'])\
    .sort(['predicted_rating'], ascending=False)
pd.merge( movies[movies.movieId > 0], predicted_ratings, on=['movieId'])\
    [['predicted_rating', 'title', 'genres']]\
    .sort(['predicted_rating'], ascending=False)
# Out:
#      predicted_rating                                              title  \
# 36           4.800232                                     Rob Roy (1995)
# 154          4.750635                                 Rear Window (1954)
# 192          4.697819                               Groundhog Day (1993)
# 61           4.659233          Star Wars: Episode IV - A New Hope (1977)
# 22           4.658856                         Usual Suspects, The (1995)
# 198          4.626185                                        Jaws (1975)
# 190          4.625130               Bridge on the River Kwai, The (1957)
# ..                ...                                                ...
# 232          2.500746                     General's Daughter, The (1999)
# 236          2.497320                               Haunting, The (1999)
# 241          2.378188                                   Bowfinger (1999)
# 235          2.368497                                 Lake Placid (1999)
# 60           2.298259                                      Junior (1994)
# 279          2.251817  Star Wars: Episode II - Attack of the Clones (...
# 97           2.249980                                   Coneheads (1993)
#
#                            genres
# 36       Action|Drama|Romance|War
# 154              Mystery|Thriller
# 192        Comedy|Fantasy|Romance
# 61        Action|Adventure|Sci-Fi
# 22         Crime|Mystery|Thriller
# 198                 Action|Horror
# 190           Adventure|Drama|War
# ..                            ...
# 232  Crime|Drama|Mystery|Thriller
# 236               Horror|Thriller
# 241                        Comedy
# 235               Horror|Thriller
# 60                  Comedy|Sci-Fi
# 279  Action|Adventure|Sci-Fi|IMAX
# 97                  Comedy|Sci-Fi
#
# [314 rows x 3 columns]

# %%
a = ratingMovies(userid)

# %%
predictRating(userid)


pd.DataFrame(predictRating(userid),columns=['movieId', 'predicted_rating'])
# Out:
#       movieId  predicted_rating
# 0           1          3.829405
# 1           2          2.953745
# 2           3          2.852389
# 3           5          1.833474
# 4           6          4.059092
# 5           7          3.063343
# 6          10          3.548711
# ...       ...               ...
# 1368   104841          3.241119
# 1369   106487          3.250371
# 1370   106782          4.100573
# 1371   109487          4.004540
# 1372   111362          3.893279
# 1373   111759          3.498358
# 1374   112852          4.100417
#
# [1375 rows x 2 columns]

# %%
## 5번 유저의 별점 예측 
#elapse()
userid=5

pd.merge( ratingMovies(userid), 
         pd.DataFrame(predictRating(userid),columns=['movieId', 'predicted_rating']),on=['movieId'], how='outer')\
        .sort(['predicted_rating'], ascending =False).dropna()
#print (predictRating(userid,20,distance_euclidean))
#elapse("end")
# Out:
#     userId  movieId  rating   timestamp  \
# 1        5      318     3.5  1230545057
# 0        5       50     4.5  1230545117
# 4        5      858     4.5  1230545060
# 13       5     2959     4.0  1230550119
# 31       5    60069     4.0  1230544505
# 2        5      613     4.0  1230543957
# 26       5    31878     3.0  1230682787
# ..     ...      ...     ...         ...
# 29       5    51662     3.0  1230544933
# 12       5     2858     1.5  1230550100
# 28       5    48385     2.5  1230544541
# 5        5      915     3.5  1230544549
# 6        5      916     3.0  1230550222
# 22       5     6283     2.0  1230544587
# 7        5     1416     2.5  1230544521
#
#                                                 title  \
# 1                    Shawshank Redemption, The (1994)
# 0                          Usual Suspects, The (1995)
# 4                               Godfather, The (1972)
# 13                                  Fight Club (1999)
# 31                                      WALL·E (2008)
# 2                                    Jane Eyre (1996)
# 26                    Kung Fu Hustle (Gong fu) (2004)
# ..                                                ...
# 29                                         300 (2007)
# 12                             American Beauty (1999)
# 28  Borat: Cultural Learnings of America for Make ...
# 5                                      Sabrina (1954)
# 6                                Roman Holiday (1953)
# 22  Cowboy Bebop: The Movie (Cowboy Bebop: Tengoku...
# 7                                        Evita (1996)
#
#                                          genres  predicted_rating
# 1                                   Crime|Drama          4.625853
# 0                        Crime|Mystery|Thriller          4.500493
# 4                                   Crime|Drama          4.492323
# 13                  Action|Crime|Drama|Thriller          4.423648
# 31  Adventure|Animation|Children|Romance|Sci-Fi          4.284680
# 2                                 Drama|Romance          4.005063
# 26                                Action|Comedy          4.001054
# ..                                          ...               ...
# 29                      Action|Fantasy|War|IMAX          3.739620
# 12                                 Comedy|Drama          3.675548
# 28                                       Comedy          3.502703
# 5                                Comedy|Romance          3.496989
# 6                          Comedy|Drama|Romance          3.435711
# 22             Action|Animation|Sci-Fi|Thriller          3.142356
# 7                                 Drama|Musical          3.084250
#
# [16 rows x 7 columns]

# %% [markdown]
# ## 성능평가 : RMSE 값으로 확인
# * 비 개인화의 RMSE 값 : 평균 별점을 예측
# * 개인화된 RMSE값 비교 Item Based
# * 데이터가 늘어남에 따라 어떻게 성능이 좋아지는?

# %%
eval_ratings = ratings

# %%
## evaluation

eval_ds = pd.merge(eval_ratings, 
                   ratings[['movieId','rating']].groupby(['movieId']).mean().reset_index(), 
                   on='movieId', how='left')

eval_ds = eval_ds.rename(columns= {'rating_x':'rating', 'rating_y':'mean_rating'})
eval_ds['predict_rating'] = 0

# %%
eval_ds['predict_rating'] = 0
## udpate to predict_rating 
distance_functions = [ ('euclidean',distance_euclidean), ('cosine', distance_cosine), ('pearson', disance_corr) ]

for name, func in distance_functions:
    eval_ds[name] = 0
    for userId in ratings['userId'].drop_duplicates().values[:10]:
        for x in predictRating(userId,20,func):
            eval_ds.loc[(eval_ds.userId==userId) & (eval_ds.movieId==x[0]),name]=x[1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-17b9c76a4a27> in <module>()
#       6     eval_ds[name] = 0
#       7     for userId in ratings['userId'].drop_duplicates().values[:]:
# ----> 8         for x in predictRating(userId,20,func):
#       9             eval_ds.loc[(eval_ds.userId==userId) & (eval_ds.movieId==x[0]),name]=x[1]
#
# <ipython-input-29-8018f7d09ab3> in predictRating(userid, nn, simFunc)
#       2
#       3     ## neighboorhood
# ----> 4     neighbor = nearest_neighbor_user(userid,nn,simFunc)
#       5     neighbor_id = [id for id,sim in neighbor]
#       6
#
# <ipython-input-21-2ae6c80634b7> in nearest_neighbor_user(user, topN, simFunc)
#      11             continue
#      12         for i in ratedIndex:
# ---> 13             if False==math.isnan(row[i]):
#      14                 interSectionU1.append(u1[i])
#      15                 interSectionU2.append(row[i])
#
# /Users/goodvc/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     482     def __getitem__(self, key):
#     483         try:
# --> 484             result = self.index.get_value(self, key)
#     485
#     486             if not np.isscalar(result):
#
# /Users/goodvc/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1186         know what you're doing
#    1187         """
# -> 1188         s = _values_from_object(series)
#    1189         k = _values_from_object(key)
#    1190
#
# /Users/goodvc/anaconda/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.values_from_object (pandas/lib.c:4108)()
#
# /Users/goodvc/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in get_values(self)
#     995     def get_values(self):
#     996         """ same as values (but handles sparseness conversions); is a view """
# --> 997         return self._data.values
#     998
#     999     def tolist(self):
#
# /Users/goodvc/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in values(self)
#    3165     @property
#    3166     def values(self):
# -> 3167         return self._values.view()
#    3168
#    3169     @property
#
# /Users/goodvc/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _values(self)
#    3086     @property
#    3087     def _values(self):
# -> 3088         return self._block.values
#    3089
#    3090     def reindex(self, new_axis, indexer=None, method=None, fill_value=None,
#
# KeyboardInterrupt:

# %%
eval_ds[eval_ds.cosine > 0]

# %%
def RMSE(X, left_col, right_col):
    return(np.sqrt(np.mean((X[left_col] - X[right_col])**2)))

def MAE(X, left_col, right_col):
    return(np.mean(np.absolute(X[left_col] - X[right_col])) )

distance_functions = [ ('euclidean',distance_euclidean), ('cosine', distance_cosine), ('pearson', disance_corr) ]

print ("MAE of {0} is {1}".format('mean rating', MAE( eval_ds[eval_ds['mean_rating'] > 0], 'rating', 'mean_rating' )))
for (name,func) in distance_functions:
    print ("MAE of {0} is {1} ".format(name, MAE( eval_ds[eval_ds[name] > 0], 'rating', name )))

print ("RMSE of {0} is {1}".format('mean rating', RMSE( eval_ds[eval_ds['mean_rating'] > 0], 'rating', 'mean_rating' )))
for (name,func) in distance_functions:
    print ("RMSE of {0} is {1} ".format(name, RMSE( eval_ds[eval_ds[name] > 0], 'rating', name )))
# Out:
# MAE of mean rating is 0.705516884009
# MAE of euclidean is 0.202162582787
# MAE of cosine is 0.445364633853
# MAE of pearson is 0.487945810423
# RMSE of mean rating is 0.920840633867
# RMSE of euclidean is 0.280518928251
# RMSE of cosine is 0.524926376986
# RMSE of pearson is 0.623947327793

# %%
eval_ds.count()
# Out:
# userId            100023
# movieId           100023
# rating            100023
# timestamp         100023
# mean_rating       100023
# predict_rating    100023
# euclidean         100023
# cosine            100023
# pearson           100023
# dtype: int64

# %%
0.689750383274
0.534087559871
0.869298083996
0.674865577278
# Out:
# 0.674865577278

# %%
for id,row in nn_rated.iteritems():
    jsum=0
    wsum=0
    for v in row.dropna().items():
        jsum += similarities.loc[v[0]]['sim']
        wsum += (v[1]*similarities.loc[v[0]]['sim'])
    print ("{0} : {1}".format(id, wsum/jsum))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-85a49a48c9b9> in <module>()
# ----> 1 for id,row in nn_rated.iteritems():
#       2     jsum=0
#       3     wsum=0
#       4     for v in row.dropna().items():
#       5         jsum += similarities.loc[v[0]]['sim']
#
# NameError: name 'nn_rated' is not defined
