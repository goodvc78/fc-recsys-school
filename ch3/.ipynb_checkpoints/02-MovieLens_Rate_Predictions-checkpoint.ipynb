# %%
# coding: utf-8

import pandas as pd
import numpy as np
from matplotlib import rcParams
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import networkx as nx
from datetime import datetime
import gensim, logging
import matplotlib.patches as mpatches
import matplotlib
# %matplotlib inline  

rcParams['font.family'] = 'NanumGothic'
rcParams.update({'font.size': 12})
matplotlib.style.use('ggplot')
sns.set_style("whitegrid")

# %% [markdown]
# ## 무비 렌즈 데이터로 별점을 예측해 보자
# * User Based 별점 예측
# * Item(Movie) Based 별점 예측

# %% [markdown]
# Movie Lens 데이터 로드
# http://grouplens.org/datasets/movielens/

# %%
def movieLensDataLoad(type):
    ## user 영화 별점 data 
    ratings = pd.read_csv("/Users/goodvc/Documents/data-analytics/movie-recommendation/"+type+"/ratings.csv")

    ## movie meta(타이트,장르) data 
    movies = pd.read_csv("/Users/goodvc/Documents/data-analytics/movie-recommendation/"+type+"/movies.csv")

    ## user가 영화에 tag를 기입한 data
    tags = pd.read_csv("/Users/goodvc/Documents/data-analytics/movie-recommendation/"+type+"/tags.csv")
    # tags = pd.read_csv("/Users/goodvc/Documents/data-analytics/movie-recommendation/ml-20m/tags.csv")
    return ( ratings, movies, tags )

#ratings, movies, tags = movieLensDataLoad('ml-20m')
ratings, movies, tags = movieLensDataLoad('ml-latest-small')

# %%
#ratings = pd.read_csv("movieLens/ml-latest-small/ratings.csv")
ratings.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        6       2  980730861
# 1       1       22       3  980731380
# 2       1       32       2  980731926
# 3       1       50       5  980732037
# 4       1      110       4  980730408
# 5       1      164       3  980731766
# 6       1      198       3  980731282
# 7       1      260       5  980730769
# 8       1      296       4  980731208
# 9       1      303       3  980732235

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
tags.head(10)
# Out:
#    userId  movieId               tag   timestamp
# 0      40        1         animation  1306926135
# 1      40        1           fantasy  1306926130
# 2      40        1             Pixar  1306926133
# 3      40       47              dark  1306930201
# 4      40       47        disturbing  1306930291
# 5      40       47          thriller  1306930308
# 6      40      101   off-beat comedy  1307009664
# 7      40      101      Wes Anderson  1307009667
# 8      40      208  post-apocalyptic  1306930611
# 9      40      208            sci-fi  1306930614

# %%
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100023.000000  100023.000000  100023.000000  1.000230e+05
# mean      341.760765    8613.123442       3.491362  1.091520e+09
# std       193.849755   19736.006106       1.067942  1.633577e+08
# min         1.000000       1.000000       0.500000  8.285049e+08
# 25%       180.000000     783.000000       3.000000  9.606706e+08
# 50%       343.000000    2081.000000       3.500000  1.097974e+09
# 75%       511.000000    4367.000000       4.000000  1.205150e+09
# max       706.000000  129651.000000       5.000000  1.427755e+09

# %% [markdown]
# ### User Based 별점 예측
#
# U(User)
# M(Movie)
#
# 1. U X M vector Matrix를 만든다.
#  key가 userid, value가 { 'movieId':rating }
# 2. 나와 비슷한 유저를 찾는다.

# %%
## 1. U X M vector Matrix를 만든다. 
UM_matrix_ds = ratings.pivot(index='userId', columns='movieId', values='rating')

# %%
UM_matrix_ds.head()
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           NaN     NaN     NaN     NaN     NaN       2     NaN     NaN
# 2           NaN       4     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN       4     NaN       4     NaN       4     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  9       10       ...    121271  122284  122495  122756  123109  \
# userId                    ...
# 1           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
#
# movieId  124857  125916  126407  129454  129651
# userId
# 1           NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 8552 columns]

# %%
index = 0
movie_sets = set()
uid_sets = set()
matrix_cnt = [[1,1,1]]
for idx, row in ratings[:].iterrows():
    index += 1
    movie_sets.add(row.movieId)
    uid_sets.add(row.userId)
    if index % 100 == 0:
        matrix_cnt.append([ len(uid_sets), len(movie_sets), index ])

# %%
cnt_info = pd.DataFrame(matrix_cnt,columns=['uid_cnt','movie_cnt', 'rating_cnt'])

# %%
cnt_info.head()
# Out:
#    uid_cnt  movie_cnt  rating_cnt   sparsity
# 0        1          1           1   0.000000
# 1        1        100         100   0.000000
# 2        2        192         200  47.916667
# 3        3        267         300  62.546816
# 4        3        347         400  61.575408

# %%
cnt_info ['sparsity'] = cnt_info.apply( lambda r : (1 - ((r.rating_cnt) / (r.uid_cnt*r.movie_cnt)))*100 , axis=1)

# %%
cnt_info ['nan-cnt'] = cnt_info.apply( lambda r : r.uid_cnt*r.movie_cnt - r.rating_cnt , axis=1)

# %%
#ax  = cnt_info['sparsity'][::100].plot(figsize=(10,10))


fig = plt.figure(figsize=(10, 6))
plt.plot( cnt_info['movie_cnt'], cnt_info['nan-cnt'])
plt.xlabel('Movie-cnt(items)')
plt.ylabel('NaN-cnt')

# %%
cnt_info.head(100)
# Out:
#     uid_cnt  movie_cnt  rating_cnt   sparsity
# 0         1          1           1   0.000000
# 1         1        100         100   0.000000
# 2         2        192         200  47.916667
# 3         3        267         300  62.546816
# 4         3        347         400  61.575408
# 5         5        415         500  75.903614
# 6         7        463         600  81.487195
# 7         7        530         700  81.132075
# 8         7        615         800  81.416957
# 9         9        663         900  84.917044
# ..      ...        ...         ...        ...
# 90       83       2821        9000  96.156195
# 91       85       2826        9100  96.211648
# 92       87       2839        9200  96.275198
# 93       88       2839        9300  96.277498
# 94       89       2849        9400  96.292805
# 95       90       2876        9500  96.329779
# 96       90       2882        9600  96.298867
# 97       91       2883        9700  96.302691
# 98       91       2884        9800  96.265870
# 99       91       2887        9900  96.231687
#
# [100 rows x 4 columns]

# %%
pd.options.display.max_rows=20

# %% [markdown]
# ### small dataset
# matrix(UM) 706 X 8552 = 6037712 <br>
# NA count = 5937689 (98.34336251878196%)
#
# * 실제로 전체의 98.3%가 빈값을 구성 되었네요..
# 매우 spase한 vector matrix가 만들어 졌네요.
#
# ### 20m dataset
# matrix(UM) 138493 X 26744 = 3703856792
# NA count = 3683856529 (99.46001521864456%)
#
# * 실제로 전체의 99.4%가 빈값을 구성 되었네요..
# 매우 spase한 vector matrix가 만들어 졌네요.

# %%
## 그럼 이제 최근접 이웃을 찾차 보자
## 
import math
from operator import itemgetter

simFunc=lambda a,b: pearsonr(a,b)[0]
def distance_cosine(a,b):
    return 1-spatial.distance.cosine(a,b)

def disance_corr(a,b):
    return pearsonr(a,b)[0]

def distance_euclidean(a,b):
    return 1/(spatial.distance.euclidean(a,b)+1)

# %%
def nearest_neighbor_user( user, topN, simFunc ) :  
    u1 = UM_matrix_ds.loc[user].dropna()
    ratedIndex = u1.index
    nn = {}
    
    ## Brote Force Compute
    for uid, row in UM_matrix_ds.iterrows():
        interSectionU1 = []
        interSectionU2 = []
        if uid==user:
            continue
        for i in ratedIndex:
            if False==math.isnan(row[i]):
                interSectionU1.append(u1[i])
                interSectionU2.append(row[i])
        interSectionLen = len(interSectionU1)
        
        ## At least 3 intersection items
        if interSectionLen < 3 :
            continue
            
        ## similarity functon
        sim = simFunc(interSectionU1,interSectionU2)
        
        if  math.isnan(sim) == False:
            nn[uid] = sim
            
    ## top N returned         
    return sorted(nn.items(),key=itemgetter(1))[:-(topN+1):-1]

# %%
def predictRating(userid, nn=100, simFunc=distance_cosine) :
   
    ## neighboorhood 
    neighbor = nearest_neighbor_user(userid,nn,simFunc)
    neighbor_id = [id for id,sim in neighbor]
    
    ## neighboorhood's movie : al least 4 ratings
    neighbor_movie = UM_matrix_ds.loc[neighbor_id]\
                    .dropna(1, how='all'\
                    , thresh = 4 )
    neighbor_dic = (dict(neighbor))
    ret = [] # ['movieId', 'predictedRate']
    
    ## rating predict by my similarities 
    for movieId, row in neighbor_movie.iteritems():
        jsum, wsum = 0, 0
        for v in row.dropna().iteritems():
            sim = neighbor_dic.get(v[0],0)
            jsum += sim
            wsum += (v[1]*sim)
        ret.append([movieId, wsum/jsum])
       
    return ret

# %%
def ratingMovies(userid):
    return pd.merge(ratings[ratings.userId==userid], movies, on=['movieId'])

# %%
gtime=time.time()
def elapse(string=""):
    global gtime
    now = time.time()
    if string!="":
        print ("{1} : {0} sec".format(now - gtime, string))
    gtime = now

# %%
userid=1
pd.options.display.max_rows=14
ratingMovies(userid).sort(['rating'],ascending=False)[['rating','title','genres']].head(100)
# Out:
#      rating                                              title  \
# 226       5                       M*A*S*H (a.k.a. MASH) (1970)
# 45        5                  E.T. the Extra-Terrestrial (1982)
# 30        5                         Mission: Impossible (1996)
# 33        5               Independence Day (a.k.a. ID4) (1996)
# 34        5                              Godfather, The (1972)
# 121       5                                 Poltergeist (1982)
# 202       5                                     Starman (1984)
# ..      ...                                                ...
# 123       4                               Lethal Weapon (1987)
# 161       3                                 In Too Deep (1999)
# 143       3  Name of the Rose, The (Name der Rose, Der) (1986)
# 145       3                                   Westworld (1973)
# 147       3          Conquest of the Planet of the Apes (1972)
# 151       3                                          Go (1999)
# 139       3              Pope of Greenwich Village, The (1984)
#
#                                 genres
# 226                   Comedy|Drama|War
# 45               Children|Drama|Sci-Fi
# 30   Action|Adventure|Mystery|Thriller
# 33    Action|Adventure|Sci-Fi|Thriller
# 34                         Crime|Drama
# 121                    Horror|Thriller
# 202     Adventure|Drama|Romance|Sci-Fi
# ..                                 ...
# 123          Action|Comedy|Crime|Drama
# 161                    Action|Thriller
# 143       Crime|Drama|Mystery|Thriller
# 145     Action|Sci-Fi|Thriller|Western
# 147                      Action|Sci-Fi
# 151                       Comedy|Crime
# 139                              Drama
#
# [100 rows x 3 columns]

# %%
userid=1
print (userid)
predicted_ratings = pd.DataFrame(predictRating(userid),columns=['movieId', 'predicted_rating'])\
    .sort(['predicted_rating'], ascending=False)
pd.merge( movies[movies.movieId > 0], predicted_ratings, on=['movieId'])\
    [['predicted_rating', 'title', 'genres']]\
    .sort(['predicted_rating'], ascending=False)
# Out:
# 1
#      predicted_rating                                              title  \
# 36           4.800232                                     Rob Roy (1995)
# 154          4.750635                                 Rear Window (1954)
# 192          4.697819                               Groundhog Day (1993)
# 61           4.659233          Star Wars: Episode IV - A New Hope (1977)
# 22           4.658856                         Usual Suspects, The (1995)
# 198          4.626185                                        Jaws (1975)
# 190          4.625130               Bridge on the River Kwai, The (1957)
# ..                ...                                                ...
# 232          2.500746                     General's Daughter, The (1999)
# 236          2.497320                               Haunting, The (1999)
# 241          2.378188                                   Bowfinger (1999)
# 235          2.368497                                 Lake Placid (1999)
# 60           2.298259                                      Junior (1994)
# 279          2.251817  Star Wars: Episode II - Attack of the Clones (...
# 97           2.249980                                   Coneheads (1993)
#
#                            genres
# 36       Action|Drama|Romance|War
# 154              Mystery|Thriller
# 192        Comedy|Fantasy|Romance
# 61        Action|Adventure|Sci-Fi
# 22         Crime|Mystery|Thriller
# 198                 Action|Horror
# 190           Adventure|Drama|War
# ..                            ...
# 232  Crime|Drama|Mystery|Thriller
# 236               Horror|Thriller
# 241                        Comedy
# 235               Horror|Thriller
# 60                  Comedy|Sci-Fi
# 279  Action|Adventure|Sci-Fi|IMAX
# 97                  Comedy|Sci-Fi
#
# [314 rows x 3 columns]

# %%
## 5번 유저의 별점 예측 
elapse()
userid=10

pd.merge(ratingMovies(userid),predictRating(userid),on=['movieId'], how='outer')\
        .sort(['predictedRate'], ascending =False)
#print (predictRating(userid,20,distance_euclidean))
elapse("end")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-246-7ba3cf5941ba> in <module>()
#       3 userid=10
#       4
# ----> 5 pd.merge(ratingMovies(userid),predictRating(userid),on=['movieId'], how='outer')        .sort(['predictedRate'], ascending =False)
#       6 #print (predictRating(userid,20,distance_euclidean))
#       7 elapse("end")
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/tools/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy)
#      36                          right_on=right_on, left_index=left_index,
#      37                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 38                          copy=copy)
#      39     return op.get_result()
#      40 if __debug__:
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/tools/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy)
#     182         (self.left_join_keys,
#     183          self.right_join_keys,
# --> 184          self.join_names) = self._get_merge_keys()
#     185
#     186     def get_result(self):
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/tools/merge.py in _get_merge_keys(self)
#     342                 else:
#     343                     if not is_rkey(rk):
# --> 344                         right_keys.append(right[rk].values)
#     345                         if lk == rk:
#     346                             # avoid key upcast in corner case (length-0)
#
# TypeError: list indices must be integers, not str

# %%
print (predictRating(userid,20,distance_euclidean))
# Out:
# [[1, 3.2247194110570208], [3, 2.9999999999999996], [6, 4.0970605549331562], [17, 3.5408838538294267], [19, 2.7187638431597523], [25, 3.9255822102693072], [29, 3.5113718877199043], [32, 3.9995634839760172], [34, 3.371165753571542], [36, 4.0], [39, 3.3674238341453266], [41, 3.7500000000000004], [43, 3.607311265295952], [47, 3.8514368894422524], [50, 4.4074787578950767], [95, 3.1843729383129085], [110, 4.192130921702562], [150, 3.8736751083781527], [151, 3.0000000000000004], [161, 4.1894494688778821], [162, 3.9772562245601919], [165, 3.1944028307437913], [168, 3.3979879511384099], [170, 2.517749202644787], [198, 3.267057831579856], [231, 2.6932485551908054], [253, 3.088560332950459], [260, 3.880976547208951], [265, 3.8133900323978978], [293, 3.7931536198802185], [296, 4.2330700904745777], [316, 3.2531680728000629], [318, 4.2555561499772638], [329, 2.3823015073603422], [344, 3.0258523677212783], [345, 3.7882677709539339], [349, 3.3846716882615424], [356, 4.1336654513595414], [357, 3.9207591880793857], [364, 3.4895874866182606], [367, 2.5400783793772708], [377, 3.2062284504830614], [380, 3.1762631185542416], [410, 3.1045909429479512], [442, 3.240786854963642], [457, 3.9759347574339992], [480, 3.671159329683348], [497, 3.7859104409086179], [500, 3.0587940698486173], [508, 3.4814296615348006], [509, 3.5341798490231264], [515, 4.0420033426210447], [520, 3.2803436477805499], [527, 4.2514403685216937], [538, 3.537208894865346], [539, 3.0454202585047061], [541, 3.6956940176274466], [551, 3.5728937238707985], [555, 4.1944028307437913], [586, 2.6996960508754353], [587, 2.445055535842946], [588, 3.5553219835743968], [589, 3.7426919610772735], [590, 3.537208894865346], [592, 3.5484986965287586], [593, 4.3329996601001053], [595, 3.7306997268618529], [597, 3.2640815466627844], [608, 4.4478706767713856], [648, 3.3797894568902418], [673, 3.4143652350299276], [708, 3.2620518345933598], [733, 3.5092719691403893], [736, 3.2076395179741528], [750, 4.2674829060022219], [778, 4.0911952344153972], [780, 3.2323886761663649], [788, 2.8058133422980189], [838, 4.2970223869876927], [849, 3.0], [858, 4.1487840109745564], [866, 4.0], [913, 3.8576990389074255], [914, 3.4981202042750184], [919, 3.6345353531790376], [924, 3.713823258649974], [1028, 3.4417008394081376], [1036, 4.3079675458505893], [1047, 3.9017637098340652], [1059, 3.9809746860682633], [1073, 3.0], [1089, 3.6895400861209451], [1097, 3.3392576626495196], [1101, 3.3079521933090321], [1136, 3.5311240858238944], [1183, 3.9546489217594041], [1196, 3.8943854329339183], [1197, 4.1866360255679682], [1198, 4.144323707897752], [1200, 4.3122992250042129], [1210, 3.6953735024918677], [1213, 4.2969721195162176], [1214, 3.7655062496233516], [1220, 3.4296758107001515], [1221, 4.5449491568979221], [1222, 3.7259403257193693], [1225, 3.5632700190966311], [1234, 4.3403572815199292], [1240, 3.2918897627528296], [1246, 3.8755244155531861], [1252, 3.241408912789665], [1259, 3.7763863127434432], [1265, 3.1707238173167136], [1266, 3.8886528097865236], [1270, 3.6920418568292486], [1291, 3.5844978087402311], [1293, 4.1069793877817045], [1307, 3.6955537796126019], [1356, 3.3954618844142019], [1357, 4.1792755376026314], [1358, 4.1609057698763285], [1372, 2.5414067822097786], [1374, 3.5140880484995978], [1387, 3.7516806799067766], [1393, 3.7086960539552742], [1527, 3.3593913223667107], [1573, 3.663413434205419], [1580, 2.8011644240264144], [1584, 3.4770251610908529], [1610, 3.8713190111728357], [1617, 3.8113123023483224], [1704, 4.0081065964101805], [1721, 3.5298450490684528], [1917, 3.3651213555982067], [1923, 2.9587072833751726], [1960, 3.2282645506142185], [1968, 3.7216963013026474], [2028, 3.8630922332951925], [2115, 3.2576168931054106], [2268, 3.7283707819840806], [2324, 3.8342256013773603], [2542, 3.0114909738659832], [2571, 4.0910049075404462], [2628, 3.8991635703708267], [2683, 2.0568865322589005], [2706, 3.3473192881988187], [2762, 3.7330700997724051], [2959, 3.985775360477037], [3114, 3.5939780578867797], [3147, 4. ...

# %%
columns
# Out:
# userId       20000263
# movieId      20000263
# rating       20000263
# timestamp    20000263
# dtype: int64

# %% [markdown]
# ## 성능평가 : RMSE 값으로 확인
# * 비 개인화의 RMSE 값 : 평균 별점을 예측
# * 개인화된 RMSE값 비교 Item Based
# * 데이터가 늘어남에 따라 어떻게 성능이 좋아지는?

# %%
## evaluation
eval_ds = pd.merge(ratings, 
                   ratings[['movieId','rating']].groupby(['movieId']).mean().reset_index(), 
                   on='movieId', how='left')

eval_ds = eval_ds.rename(columns= {'rating_x':'rating', 'rating_y':'mean_rating'})
eval_ds['predict_rating'] = 0

# %%
eval_ds['predict_rating'] = 0
## udpate to predict_rating 
distance_functions = [ ('euclidean',distance_euclidean), ('cosine', distance_cosine), ('pearson', disance_corr) ]

for name, func in distance_functions:
    eval_ds[name] = 0
    for userId in ratings['userId'].drop_duplicates().values:
        for x in predictRating(userId,20,func):
            eval_ds.loc[(eval_ds.userId==userId) & (eval_ds.movieId==x[0]),name]=x[1]

# %%
eval_ds[eval_ds.cosine > 0].head()
# Out:
#      userId  movieId  rating   timestamp  mean_rating  predict_rating  \
# 8         1      296       4   980731208     4.137615               0
# 28        1      593       5   980731433     4.235905               0
# 33        1      780       5   980731988     3.469008               0
# 150       1     2571       4   980730794     4.207547               0
# 230       2       50       4  1091931562     4.368201               0
#
#      euclidean   consine   pearson    cosine
# 8            0  4.249598  0.000000  4.249598
# 28           5  4.500049  0.000000  4.500049
# 33           0  4.000633  4.243071  4.000633
# 150          0  4.624907  0.000000  4.624907
# 230          0  4.499704  4.501111  4.499704

# %%
def RMSE(X, left_col, right_col):
    return(np.sqrt(np.mean((X[left_col] - X[right_col])**2)))

def MAE(X, left_col, right_col):
    return(np.mean(np.absolute(X[left_col] - X[right_col])) )

distance_functions = [ ('euclidean',distance_euclidean), ('cosine', distance_cosine), ('pearson', disance_corr) ]

print ("MAE of {0} is {1}".format('mean rating', MAE( eval_ds[eval_ds['mean_rating'] > 0], 'rating', 'mean_rating' )))
for (name,func) in distance_functions:
    print ("MAE of {0} is {1} ".format(name, MAE( eval_ds[eval_ds[name] > 0], 'rating', name )))

print ("RMSE of {0} is {1}".format('mean rating', RMSE( eval_ds[eval_ds['mean_rating'] > 0], 'rating', 'mean_rating' )))
for (name,func) in distance_functions:
    print ("RMSE of {0} is {1} ".format(name, RMSE( eval_ds[eval_ds[name] > 0], 'rating', name )))
# Out:
# MAE of mean rating is 0.7055168840093711
# MAE of euclidean is 0.2629332215487124
# MAE of cosine is 0.4650109666699926
# MAE of pearson is 0.5312093797417275
# RMSE of mean rating is 0.920840633867146
# RMSE of euclidean is 0.35397089006040633
# RMSE of cosine is 0.5992381164489905
# RMSE of pearson is 0.7043043690726212

# %%
eval_ds.count()
# Out:
# userId            20000263
# movieId           20000263
# rating            20000263
# timestamp         20000263
# mean_rating       20000263
# predict_rating    20000263
# dtype: int64

# %%
0.689750383274
0.534087559871
0.869298083996
0.674865577278
# Out:
#       movieId  predictedRate                                         title
# 1           1       3.604548                              Toy Story (1995)
# 7           7       3.956180                                Sabrina (1995)
# 95         95       3.715045                           Broken Arrow (1996)
# 780       780       4.243071          Independence Day (a.k.a. ID4) (1996)
# 2683     2683       2.906671  Austin Powers: The Spy Who Shagged Me (1999)
# 2688     2688       3.736359                General's Daughter, The (1999)
# 2701     2701       1.750000                         Wild Wild West (1999)
# 2706     2706       2.425205                           American Pie (1999)
# 2713     2713       2.434502                            Lake Placid (1999)
# 2716     2716       4.250102    Ghostbusters (a.k.a. Ghost Busters) (1984)
# 2719     2719       2.478034                          Haunting, The (1999)
# 2723     2723       2.445416                            Mystery Men (1999)
# 2762     2762       3.840667                       Sixth Sense, The (1999)
# 2763     2763       2.462713               Thomas Crown Affair, The (1999)
# 2770     2770       3.241659                              Bowfinger (1999)
# 2805     2805       1.962458                       Mickey Blue Eyes (1999)
# 2826     2826       1.963525                      13th Warrior, The (1999)
# 2881     2881       3.148615                        Double Jeopardy (1999)
# 2987     2987       3.495634               Who Framed Roger Rabbit? (1988)

# %%
for id,row in nn_rated.iteritems():
    jsum=0
    wsum=0
    for v in row.dropna().items():
        jsum += similarities.loc[v[0]]['sim']
        wsum += (v[1]*similarities.loc[v[0]]['sim'])
    print ("{0} : {1}".format(id, wsum/jsum))
# Out:
# 47 : 4.15571886580929
# 50 : 4.3706745093591035
# 110 : 4.258894070248855
# 296 : 4.187300965397262
# 318 : 4.669159331214638
# 344 : 3.714332189378028
# 356 : 4.416330561732522
# 480 : 3.1280491671238684
# 500 : 3.607917014282175
# 527 : 3.929389456979297
# 589 : 3.810787600196478
# 590 : 4.165356050627398
# 593 : 4.503391389613891
# 597 : 3.5210085244963127
# 608 : 3.694731812714421
# 1198 : 3.8263957177194405
# 1210 : 3.4039614117563164
# 1704 : 4.514166975374401
# 2028 : 4.156865802670894
# 2571 : 3.7959702197908363
# 2762 : 3.6806326896708073
# 2858 : 3.827340922074615
# 3949 : 2.9636188998406983
# 3996 : 2.70412827918192
# 4226 : 3.718070248316179
# 5445 : 3.913310521753981
# 5952 : 4.251638938695222
# 5989 : 3.9112102464163123
# 6016 : 4.2046905593468376
# 7153 : 4.119763377036935
# movieId  47    50    110   296   318   344   356   480   500   527   ...   \
# userId                                                               ...
# 498       NaN   NaN   4.0   4.0   5.0   NaN   4.0     2   NaN   NaN  ...
# 336       NaN   NaN   NaN   NaN   4.0   NaN   NaN   NaN   NaN   5.0  ...
# 321       5.0   4.0   5.0   5.0   5.0   5.0   5.0     4   NaN   4.0  ...
# 60        NaN   4.5   NaN   4.5   4.0   NaN   NaN   NaN   NaN   NaN  ...
# 24        NaN   5.0   5.0   NaN   5.0   3.0   NaN   NaN   NaN   NaN  ...
# 449       4.5   NaN   NaN   4.5   NaN   NaN   4.0   NaN   NaN   NaN  ...
# 409       NaN   NaN   4.0   4.0   5.0   NaN   NaN   NaN   2.5   NaN  ...
# 308       NaN   NaN   NaN   NaN   NaN   NaN   4.0   NaN   NaN   3.5  ...
# 26        3.0   5.0   5.0   3.0   NaN   3.0   5.0     5   5.0   4.0  ...
# 105       NaN   NaN   3.0   4.0   5.0   NaN   5.0     1   NaN   NaN  ...
# 240       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 675       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   1.0  ...
# 480       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 242       NaN   NaN   NaN   NaN   NaN   3.5   NaN   NaN   3.5   NaN  ...
# 244       4.0   4.0   4.5   4.5   5.0   NaN   4.0   NaN   NaN   NaN  ...
# 388       NaN   NaN   5.0   5.0   5.0   NaN   5.0     4   NaN   5.0  ...
# 127       5.0   NaN   3.0   NaN   NaN   4.0   5.0     3   4.0   NaN  ...
# 19        4.5   4.5   4.0   4.0   3.5   NaN   4.5   NaN   NaN   5.0  ...
# 35        NaN   NaN   NaN   NaN   5.0   NaN   NaN   NaN   NaN   NaN  ...
# 420       3.0   3.5   NaN   3.5   4.5   NaN   3.0     3   3.0   NaN  ...
#
# movieId  2762  2858  3949  3996  4226  5445  5952  5989  6016  7153
# userId
# 498       NaN   4.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 336       NaN   4.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 321       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 60        NaN   4.0     2   NaN   3.5   NaN   4.5   NaN   4.5   4.5
# 24        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 449       4.0   4.5   NaN   2.5   4.5   4.5   NaN   3.5   4.0   NaN
# 409       2.0   3.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 308       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 26        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 105       4.0   4.0     4   NaN   NaN   NaN   NaN   5.0   NaN   NaN
# 240       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 675       NaN   NaN     1   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 480       NaN   NaN   NaN   2.0   NaN   3.5   4.0   NaN   NaN   NaN
# 242       NaN   NaN   NaN   NaN   4.0   4.5   4.0   3.5   NaN   4.0
# 244       4.0   4.0   NaN   NaN   4.0   NaN   4.0   4.0   4.0   5.0
# 388       NaN   NaN   NaN   4.0   NaN   NaN   NaN   NaN   NaN   NaN
# 127       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 19        4.5   NaN     4   4.0   NaN   3.5   4.5   3.5   4.5   NaN
# 35        NaN   NaN   NaN   NaN   NaN   3.5   4.5   NaN   NaN   4.0
# 420       NaN   3.0     4   1.0   2.5   NaN   NaN   NaN   4.0   3.0
#
# [20 rows x 30 columns]
