# %% [markdown]
# # 내가 관심있는 작가의 구독자들이 좋아하는 작가 추천

# %%
import pandas as pd
import matplotlib.pylab as plt
import requests
import json
from bs4 import BeautifulSoup
# %matplotlib inline

# %%
## road pickle data
import pickle
pkl_file = open('/Users/goodvc/Data/fc-recsys-school/ch1/resource/brunch_sns.pkl', 'rb')
ds_dict = pickle.load(pkl_file)
pkl_file.close()

# %%
## 관심 작가 정보 크롤링 하기 
## extract Brunch Writer Info : uid, name, text-count, megazine-count, follower-count, following-count:
def extractWriterInfo(uid):
    try:
        response = requests.get("http://brunch.co.kr/@{uid}".format(uid=uid) )
    except Exception:
        []
        
    data = response.content.decode('utf-8')
    soup = BeautifulSoup(data, 'html.parser')
    
    ## name 
    names = soup.find_all("strong", class_="profileUserName")
    name = uid if len(names)<1 else names[0].getText()
    
    classes = soup.find_all("span", class_="num_count")
    reserved = [uid, name]
    for c in classes:
        reserved.append(int(c.getText().replace(',','')))
    return reserved

print extractWriterInfo('goodvc78')
# Out:
# ['goodvc78', u'\ucd5c\uaddc\ubbfc', 3, 1, 158, 8]

# %%
def toDataframe(src) :
    data = []
    for n, f in src.items():
        for nn in f['following']:
            data.append([n,'following',nn])
    df = pd.DataFrame(data, columns=['uid','dir','target'])
    return df[~df.target.isin(['brunch'])]

# %%
df = toDataframe(ds_dict['goodvc78'])
df = df[~df.target.isin(['goodvc78','brunch'])]

# %% [markdown]
# ### 상위 브런치 작가

# %%
## 상위 50 작가 선정 
topn=50
top_writer = df[df.dir=='following'].groupby('target').count().sort('uid', ascending=False)[:topn][['dir']]

top_writer = top_writer.reset_index()
top_writer.columns = ['uid','교차 구독자수']

## 상위 작가의 bruch 정보 가져오기 ( 크롤링 ) 
top_writer_info = []
for uid in top_writer.uid:
    top_writer_info.append(extractWriterInfo(uid))
top_writer_info = pd.DataFrame(top_writer_info, columns=['uid','작가명','글 수', '매거진수', '비교작가 구독자수', '관심작가수' ])

## 데이터 머지 
top_writer = pd.merge(top_writer, top_writer_info, on=['uid'])
top_writer['관심작가 구독자수'] = len(ds_dict['goodvc78'].keys())

## 전체 구독수대비 나의 구독자수 비율
top_writer['교차 구독자수 비율'] = top_writer['교차 구독자수'] / (top_writer['비교작가 구독자수'] + top_writer['관심작가 구독자수'] - top_writer['교차 구독자수']  )
top_writer['교차 구독자수 비율'] = top_writer['교차 구독자수 비율'].apply(lambda x: round(x,3))

# %%
top_writer.head()
# Out:
#           uid  교차 구독자수            작가명  글 수  매거진수  비교작가 구독자수  관심작가수  관심작가 구독자수  \
# 0     lifidea       54  Jin Young Kim   10     1        786    194        158
# 1  brunchflgu       40        조우성 변호사  674    10       5243     35        158
# 2    jimmyrim       40  임지훈 Jimmy Rim    6     0       2469      0        158
# 3   yoojs8512       38            유재석   46     1       1468     24        158
# 4       insuk       35      조인석 chris   10     1        939     29        158
#
#    교차 구독자수 비율
# 0       0.061
# 1       0.007
# 2       0.015
# 3       0.024
# 4       0.033

# %%
def rankBy( ds, colname, topn=10 ):
    ranked = ds.sort(colname, ascending=False)[['uid','작가명','관심작가 구독자수', '교차 구독자수','비교작가 구독자수', '교차 구독자수 비율']][:topn]
    for (name,row) in ranked.iterrows():
        print ("https://brunch.co.kr/@{name}".format(name=row['uid'], value=row['작가명']))
    return ranked
#rankBy( top_writer, '나의 구독자수')

# %%
rankBy( top_writer, '교차 구독자수')
# Out:
# https://brunch.co.kr/@lifidea
# https://brunch.co.kr/@jimmyrim
# https://brunch.co.kr/@brunchflgu
# https://brunch.co.kr/@yoojs8512
# https://brunch.co.kr/@insuk
# https://brunch.co.kr/@suhanjang
# https://brunch.co.kr/@suyoung
# https://brunch.co.kr/@pelexus
# https://brunch.co.kr/@haneulalice
# https://brunch.co.kr/@wjchee
#            uid                  작가명  관심작가 구독자수  교차 구독자수  비교작가 구독자수  교차 구독자수 비율
# 0      lifidea        Jin Young Kim        158       54        786       0.061
# 2     jimmyrim        임지훈 Jimmy Rim        158       40       2469       0.015
# 1   brunchflgu              조우성 변호사        158       40       5243       0.007
# 3    yoojs8512                  유재석        158       38       1468       0.024
# 4        insuk            조인석 chris        158       35        939       0.033
# 5    suhanjang              티거 Jang        158       31       4965       0.006
# 6      suyoung                  강수영        158       31       1265       0.022
# 7      pelexus                  최윤섭        158       27        819       0.028
# 8  haneulalice  Alice in wonderland        158       25       2570       0.009
# 9       wjchee                  지원준        158       25        468       0.042

# %%
rankBy( top_writer, '비교작가 구독자수')
# Out:
# https://brunch.co.kr/@brunchflgu
# https://brunch.co.kr/@suhanjang
# https://brunch.co.kr/@captaink
# https://brunch.co.kr/@rothem
# https://brunch.co.kr/@haneulalice
# https://brunch.co.kr/@jimmyrim
# https://brunch.co.kr/@lonelyplanet
# https://brunch.co.kr/@2kija
# https://brunch.co.kr/@sooscape
# https://brunch.co.kr/@yoonash
#              uid                  작가명  관심작가 구독자수  교차 구독자수  비교작가 구독자수  \
# 1     brunchflgu              조우성 변호사        158       40       5243
# 5      suhanjang              티거 Jang        158       31       4965
# 46      captaink                  캡틴K        158       13       3907
# 38        rothem               Rothem        158       15       2695
# 8    haneulalice  Alice in wonderland        158       25       2570
# 2       jimmyrim        임지훈 Jimmy Rim        158       40       2469
# 49  lonelyplanet        론리플래닛 매거진 코리아        158       13       2292
# 33         2kija                이기주작가        158       16       2234
# 12      sooscape                   흔디        158       24       1758
# 13       yoonash              yoonash        158       24       1478
#
#     교차 구독자수 비율
# 1        0.007
# 5        0.006
# 46       0.003
# 38       0.005
# 8        0.009
# 2        0.015
# 49       0.005
# 33       0.007
# 12       0.013
# 13       0.015

# %%
rankBy( top_writer, '교차 구독자수 비율')
# Out:
# https://brunch.co.kr/@cojette
# https://brunch.co.kr/@lifidea
# https://brunch.co.kr/@chaibschaibs
# https://brunch.co.kr/@cloud09
# https://brunch.co.kr/@yannheo
# https://brunch.co.kr/@manya
# https://brunch.co.kr/@wjchee
# https://brunch.co.kr/@genie7pe
# https://brunch.co.kr/@jaeseungmun
# https://brunch.co.kr/@yper
#              uid            작가명  관심작가 구독자수  교차 구독자수  비교작가 구독자수  교차 구독자수 비율
# 19       cojette        cojette        158       21         95       0.091
# 0        lifidea  Jin Young Kim        158       54        786       0.061
# 34  chaibschaibs         CHAIBS        158       16        120       0.061
# 32       cloud09            강한별        158       16        170       0.051
# 21       yannheo            허양일        158       19        290       0.044
# 17         manya             마냐        158       21        341       0.044
# 9         wjchee            지원준        158       25        468       0.042
# 40      genie7pe   Chulhyun Cho        158       14        198       0.041
# 42   jaeseungmun   Jaeseung Mun        158       14        210       0.040
# 29          yper    문현구 YPER 대표        158       17        308       0.038

# %% [markdown]
# ---

# %% [markdown]
# # 브런치 작가 Clustering

# %%
from scipy.spatial import distance 
from scipy import stats
import seaborn as sns
import scipy

def cos_cdist(matrix, vector, dist):
    """
    Compute the cosine distances between each row of matrix and vector.
    """
    v = vector.reshape(1, -1)
    return scipy.spatial.distance.cdist(matrix, v, 'cosine').reshape(-1)

def matrix_similarity( matrix_ds, dist='jaccard'):
    
    sim_mat = []
    name = []
    for idx, row in matrix_ds.iterrows():
        name.append(idx)
        sim_mat.append(cos_cdist( matrix_ds, row, dist ).tolist())
    ds = 1-pd.DataFrame(sim_mat, columns=name, index=name)
    return ds

# %%
tmp_ds = df[df.target.isin(top_writer[:30].uid)]
writer_ds = pd.pivot_table( tmp_ds, index='target', columns='uid', values='dir', aggfunc=len, fill_value=0)
ds = matrix_similarity( writer_ds )
sns.set(style="whitegrid", palette="pastel", color_codes=True,font_scale=1.2)
cmap = sns.cubehelix_palette(as_cmap=True, rot=-.2, light=1.3)
cm = sns.clustermap(ds, cmap=cmap, linewidths=.5)
cm.fig.set_figwidth(15)
cm.fig.set_figheight(15)

# %%
for idx,row in top_writer[:30].sort('uid').iterrows():
    print( u"https://brunch.co.kr/@{uid} {name}".format(uid=row.uid, name=row['작가명']))
# Out:
# https://brunch.co.kr/@borashow 보라쇼
# https://brunch.co.kr/@breakthrough 한국현
# https://brunch.co.kr/@brunch4nrs 윤청하
# https://brunch.co.kr/@brunchflgu 조우성 변호사
# https://brunch.co.kr/@cojette cojette
# https://brunch.co.kr/@haneulalice Alice in wonderland
# https://brunch.co.kr/@hmin0606 신유민
# https://brunch.co.kr/@imagineer 더할 나위 없이
# https://brunch.co.kr/@insuk 조인석 chris
# https://brunch.co.kr/@jihoonjeong 정지훈
# https://brunch.co.kr/@jimmyrim 임지훈 Jimmy Rim
# https://brunch.co.kr/@kkonal 꼬날
# https://brunch.co.kr/@lifidea Jin Young Kim
# https://brunch.co.kr/@manya 마냐
# https://brunch.co.kr/@meanimize Meanimize
# https://brunch.co.kr/@mobiinside Mobiinside
# https://brunch.co.kr/@pelexus 최윤섭
# https://brunch.co.kr/@promise4u 양준철
# https://brunch.co.kr/@sapu0000 송준협
# https://brunch.co.kr/@sclplus 엄지용
# https://brunch.co.kr/@sooscape 흔디
# https://brunch.co.kr/@sshong 홍순성
# https://brunch.co.kr/@suhanjang 티거 Jang
# https://brunch.co.kr/@suyoung 강수영
# https://brunch.co.kr/@wjchee 지원준
# https://brunch.co.kr/@yannheo 허양일
# https://brunch.co.kr/@yoojs8512 유재석
# https://brunch.co.kr/@yoonash yoonash
# https://brunch.co.kr/@yper 문현구 YPER 대표
# https://brunch.co.kr/@yunjungseo Yunjung Seo

# %% [markdown]
# ### 클러스터 1번
# UX, 디자인 관련 글이 주를 이루는 UX,디자인,기획을 업으로 하시는 작가분
# * https://brunch.co.kr/@yunjungseo Yunjung Seo
# * https://brunch.co.kr/@hmin0606 신유민
# * https://brunch.co.kr/@suyoung 강수영
# * https://brunch.co.kr/@meanimize Meanimize
# * https://brunch.co.kr/@sooscape 흔디
# * https://brunch.co.kr/@sapu0000 송준협
# ---
# ### 클러스터 2번
# 개발자 문화에 관련된 글이 주를 이루는 개발을 업으로하시는 작가분(대체적으로 글수가 10개 이하로 적음)
# * https://brunch.co.kr/@brunch4nrs 윤청하
# * https://brunch.co.kr/@brunchlftm sbroh
# * https://brunch.co.kr/@insuk 조인석 chris
# * https://brunch.co.kr/@pelexus 최윤섭
# ---
# ### 클러스터 3번
# 스타트업 문화, 회사의 생활, 직무, 업무 멘토링 등과 관련된 글이 많은 작가분들임
# * https://brunch.co.kr/@promise4u 양준철
# * https://brunch.co.kr/@yoonash yoonash
# * https://brunch.co.kr/@aboutheman 퀘벤하운
# * https://brunch.co.kr/@aboutheman 퀘벤하운
# * https://brunch.co.kr/@jihoonjeong 정지훈
# * https://brunch.co.kr/@haneulalice Alice in wonderland
# * https://brunch.co.kr/@suhanjang 티거 Jang
# ---
# ### 클러스터 4번
# IT 트랜드, 컬럼, 사회 현상에 대한 내용을 담은 작가분들임
# * https://brunch.co.kr/@sclplus 엄지용
# * https://brunch.co.kr/@wjchee 지원준
# * https://brunch.co.kr/@jsksoft 상상
# * https://brunch.co.kr/@borashow 보라쇼
# * https://brunch.co.kr/@manya 마냐
# ---
# ### 클러스터 5번
# 4번 클러스터와 유사하게 IT/모바일 트렌드, 데이터과학 등 저널의 성향이 있는 작가분들임
# * https://brunch.co.kr/@genie7pe Chulhyun Cho
# * https://brunch.co.kr/@jaeseungmun Jaeseung Mun
# * https://brunch.co.kr/@sapu0000 송준협
# * https://brunch.co.kr/@jimmyrim 임지훈 Jimmy Rim
# * https://brunch.co.kr/@mobiinside Mobiinside
# * https://brunch.co.kr/@yoojs8512 유재석
# * https://brunch.co.kr/@lifidea Jin Young Kim

# %% [markdown]
# ---
# # 다양한 작가들과 함께분석

# %%
writers_dict['goodvc78']
# Out:
# {u'01134eo': {u'following': [u'goodvc78', u'brunch']},
#  u'aeterkhan': {u'following': [u'sunsutu',
#    u'goodvc78',
#    u'snowcountry',
#    u'plusclov',
#    u'jmh5531',
#    u'head77x',
#    u'brunch']},
#  u'akuku': {u'following': [u'haneulalice',
#    u'goodvc78',
#    u'jnbells',
#    u'sadrove',
#    u'vijay',
#    u'borashow',
#    u'yper',
#    u'sophia5787',
#    u'brunch']},
#  u'ami': {u'following': [u'sustainlife',
#    u'2kija',
#    u'goodvc78',
#    u'cinehvwm',
#    u'suyoung',
#    u'dalda',
#    u'suhanjang',
#    u'yunjungseo',
#    u'jimmyrim',
#    u'sooscape']},
#  u'bizzaru7': {u'following': [u'goodvc78', u'brunch']},
#  u'bohyungkimnxu': {u'following': [u'thinkboxkyle',
#    u'eomtank',
#    u'koreajb',
#    u'goodvc78',
#    u'pelexus',
#    u'pigs',
#    u'pinie',
#    u'acgroup',
#    u'brunchflgu',
#    u'raekim',
#    u'missingmay',
#    u'joohoonjake',
#    u'botongmarketer',
#    u'brunchjqcb',
#    u'insuk',
#    u'babydiary',
#    u'arambaek',
#    u'jowlee',
#    u'pubjinson',
#    u'funder2000',
#    u'hyejinchoi',
#    u'techhtml',
#    u'manya',
#    u'itsooda',
#    u'techsuda',
#    u'jaeholee',
#    u'xenix',
#    u'yannheo',
#    u'jsksoft',
#    u'marsnine',
#    u'suyoung',
#    u'suhanjang',
#    u'yoojs8512',
#    u'yongjinjinipln',
#    u'haneulalice',
#    u'1yearholiday',
#    u'lifidea',
#    u'hmin0606',
#    u'borashow',
#    u'choikop',
#    u'skpman',
#    u'msra81',
#    u'driedpersimmon',
#    u'brunchlftm',
#    u'iamquadr',
#    u'brunch']},
#  u'boymeetgirl': {u'following': [u'lifidea',
#    u'goodvc78',
#    u'aidenswmo',
#    u'yeinz',
#    u'manya',
#    u'captaink',
#    u'daljasee',
#    u'jangnoah',
#    u'airtight',
#    u'doubleshot',
#    u'ihearyou',
#    u'jade',
#    u'borashow',
#    u'homoartcus',
#    u'urbanist',
#    u'manaka',
#    u'pxdstory',
#    u'seanpyo',
#    u'lonelyplanet',
#    u'vislakr',
#    u'brunch']},
#  u'brunch2yx3': {u'following': [u'hstyle84',
#    u'captaink',
#    u'goodvc78',
#    u'gunbbang',
#    u'jihoonjeong',
#    u'babydiary',
#    u'plusclov',
#    u'jungkwon-ahn',
#    u'thebetterday',
#    u'breakthrough',
#    u'mitpiki',
#    u'vijay',
#    u'indilab',
#    u'insuk',
#    u'nitro2red',
#    u'byungmookkim',
#    u'yper',
#    u'stevenh',
#    u'misunkim',
#    u'hongpro7',
#    u'why',
#    u'toriteller',
#    u'gfsaham',
#    u'byeongjinje',
#    u'yannheo',
#    u'wherevermis',
#    u'wanleehani',
#    u'matt',
#    u'dpinkie',
#    u'bang1999',
#    u'megaonic',
#    u'xmaskid',
#    u'rhee1957',
#    u'itsooda',
#    u'sunnysideup',
#    u'songcine',
#    u'suyoung',
#    u'wo-motivator',
#    u'lllshotlll',
#    u'justgo',
#    u'bodeum',
#    u'prorange',
#    u'chanjaipuwa',
#    u'ksw3182',
#    u'tschoe56',
#    u'hoyoungchoi',
#    u'rats',
#    u'mobiinside',
#    u'pyossi',
#    u'joshuajr',
#    u'brunchflgu',
#    u'haneulalice',
#    u'aboutheman',
#    u'manya',
#    u'eliotkang',
#    u'peterpens',
#    u'brunchvvlh',
#    u'suhanjang',
#    u'brunch']},
#  u'brunch3qhe': {u'following': [u'goodvc78',
#    u'brunchflgu',
#    u'insuk',
#    u'lifidea',
#    u'bwcho75',
#    u'brunch']},
#  u'brunch7se0': {u'following': [u'goodvc78',
#    u'imagineer',
#    u'robertlee',
#    u'jamess',
#    u'datasciencedude',
#    u'aidenswmo',
#    u'jaeyeonkim',
#    u'techsuda',
#    u'thebetterday',
#    u'sng2c',
#    u'ibare',
#    u'sunghyunlim',
#    u'hika',
#    u'arawn',
#    u'ohjongin',
#    u'insuk',
#    u'techhtml',
#    u'manya',
#    u'jinkieun',
#    u'xenix',
#    u'chan',
#    u'sooscape',
#    u'speedlyh',
#    u'sapu0000',
#    u'yunjungseo',
#    u'meanimize',
#    u'mushman',
#    u'wjchee',
#    u'yongjinjinipln',
#    u'suyoung',
#    u'swizzle',
#    u'brunch4nrs',
#    u'kaldokim',
#    u'sclplus',
#    u'iamquadr',
#    u'acet',
#    u'jaeseungmun',
#    u'alden',
#    u'promise4u',
#    u'yudong',
#    u'daeheejang',
#    u'matt',
#    u'brunchlftm',
#    u'kkonal',
#    u'minieetea',
#    u'jimmyrim',
#    u'eliotkang',
#    u'jinju32',
#    u'cleancode',
#    u'borashow']},
#  u'brunch86qv': {u'following': [u'goodvc78',
#    u'roh222',
#    u'homoartcus',
#    u'toyprince',
#    u'alden',
#    u'brunch']},
#  u'brunchfkvp': {u'following': [u'goodvc78',
#    u'mobiinside',
#    u'genie7pe',
#    u'brunch']},
#  u'brunchgrz': {u'following': [u'goodvc78',
#    u'alden',
#    u'wjchee',
#    u'kyeongwook-ma',
#    u'jhwhjn',
#    u'pxdstory',
#    u'jigjang',
#    u'brunch']},
#  u'brunchjklr': {u'following': [u'goodvc78',
#    u'sunsutu',
#    u'brunchxecm',
#    u'yooncohg',
#    u'2kija',
#    u'intranet',
#    u'rothem',
#    u'wjchee',
#    u'bang1999',
#    u'elara1020',
#    u'dohyunkim',
#    u'kimandrew',
#    u'kooning11',
#    u'blade31',
#    u'brunchflgu',
#    u'brunch']},
#  u'brunchkpyr': {u'following': [u'goodvc78',
#    u'suyoung',
#    u'sooscape',
#    u'jihere1001']},
#  u'brunchlaul': {u'following': [u'goodvc78',
#    u'cayden',
#    u'ibare',
#    u'kkonal',
#    u'lifidea',
#    u'wodory',
#    u'yannheo',
#    u'sunnysideup',
#    u'brunch']},
#  u'brunchlc0o': {u'following': [u'readmoney',
#    u'ceo4',
#    u'4u4u',
#    u'goodvc78',
#    u'jamess',
#    u'zip',
#    u'dangsandage',
#    u'manya',
#    u'platum',
#    u'cpa1997',
#    u'sabumbyun',
#    u'hyosha',
#    u'yper',
#    u'jsksoft',
#    u'iammento',
#    u'yannheo',
#    u'chan',
#    u'speedlyh',
#    u'sapu0000',
#    u'meanimize',
#    u'sooscape',
#    u'wanleehani',
#    u'nitro2red',
#    u'flatdesign',
#    u'amyyoungah',
#    u'yunjungseo',
#    u'mushman',
#    u'skyscanner',
#    u'jihere1001',
#    u'katetalks',
#    u'iffu',
#    u'nachoclub',
#    u'nanta23',
#    u'dooilkim',
#    u'suyoung',
#    u'8percent',
#    u'minsangchoi',
#    u'refreshstudio',
#    u'platina02',
#    u'mobiinside',
#    u'brunchflgu',
#    u'jongsiksong',
#    u'yoojs8512',
#    u'mobizenpekr',
#    u'beautytech',
#    u'sclplus',
#    u'jinju32',
#    u'conamss',
#    u'kkonal',
#    u'jimmyrim',
#    u'mynezz',
#    u'newsquare',
#    u'hmin0606',
#    u'beatbluejoo',
#    u'borashow',
#    u'lllshotlll',
#    u'brunch']},
#  u'brunchohju': {u'following': [u'tourism',
#    u'aidenswmo',
#    u'koreajb',
#    u'taebarii',
#    u'sunsutu',
#    u'skumac',
#    u'babydiary',
#    u'goodvc78',
#    u'bookdb',
#    u'yper',
#    u'neddaland',
#    u'insuk',
#    u'wo-motivator',
#    u'hyejinchoi',
#    u'imagineer',
#    u'homoartcus',
#    u'joyjun7',
#    u'kwihun80',
#    u'habit',
#    u'yannheo',
#    u'missj1227',
#    u'goodbyepain',
#    u'head77x',
#    u'mobiinside',
#    u'sustainlife',
#    u'suyoung',
#    u'yoonjikwon',
#    u'greenpeacekorea',
#    u'funder2000',
#    u'brunch4nrs',
#    u'roseroad',
#    u'yoojs8512',
#    u'captaink',
#    u'8percent',
#    u'sfac',
#    u'haneulalice',
#    u'cojette',
#    u'cjphynmu',
#    u'stevepark',
#    u'sapu0000',
#    u'lifidea',
#    u'anglla',
#    u'cleancode',
#    u'rothem',
#    u'myte',
#    u'cli-annah',
#    u'suhanjang',
#    u'ihearyou',
#    u'brunchlftm',
#    u'brunch']},
#  u'brunchup16': {u'following': [u'goodvc78',
#    u'flatdesign',
#    u'five0203',
#    u'brunch']},
#  u'brunchvejx': {u'following': [u'goodvc78',
#    u'bwcho75',
#    u'jnbells',
#    u'ajmind',
#    u'jaehyunkim',
#    u'breakthrough',
#    u'brunch']},
#  u'brunchw2ia': {u'following': [u'goodvc78',
#    u'davidsr',
#    u'kuehyunpark',
#    u'robertlee',
#    u'imagineer',
#    u'chaeminc',
#    u'mobiinside',
#    u'futureagent',
#    u'cloud09',
#    u'yooobing',
#    u'aidenswmo',
#    u'brunchmpto',
#    u'breakthrough',
#    u'cojette',
#    u'yoojs8512',
#    u'jbbae',
#    u'lifidea',
#    u'jimmyrim',
#    u'brunch']},
#  u'brunchwboh': {u'following': [u'briancheong',
#    u'tsp',
#    u'davidsr',
#    u'goodvc78',
#    u'pigs',
#    u'scottim',
#    u'wjchee',
#    u'sclplus',
#    u'jowlee',
#    u'borashow',
#    u'jounghoyoo',
#    u'dsuh',
#    u'kkonal',
#    u'jihoonjeong',
#    u'head77x',
#    u'wanleehani',
#    u'brunchflgu',
#    u'yoojs8512',
#    u'homoartcus',
#    u'mrnoface',
#    u'brunch']},
#  u'bskim987': {u'following': [u'goodvc78', u'brunch']},
#  u'byignorance': {u'following': [u'goodvc78', u'yoonash', u'brunch']},
#  u'carvehomes': {u'following': [u'clinky85',
#    u'pelexus',
#    u'goodvc78',
#    u'cysstory',
#    u'quane',
#    u'meanimize',
#    u'brunchjnux',
#    u'hyosha',
#    u'sabumbyun',
#    u'brunch']},
#  u'chajy815': {u'following': [u'brunchflgu',
#    u'goodvc78',
#    u'insuk',
#    u'brunch']},
#  u'cheonxtqj': {u'following': [u'goodvc78',
#    u'cloud09',
#    u'95kimik',
#    u'youngwungkim',
#    u'cojette',
#    u'lifidea',
#    u'brunch']},
#  u'choijinkyu': {u'following': [u'goodvc78',
#    u'cojette',
#    u'mitchell',
#    u'brunch']},
#  u'comfreak27': {u'following': [u'cojette',
#    u'goodvc78',
#    u'aidenswmo',
#    u'alden',
#    u'lifidea',
#    u'brunch']},
#  u'cycy2222': {u'following': [u'goodvc78', u'brunch']},
#  u'daniellee8xtu': {u'following': [u'kkonal',
#    u'datasciencedude',
#    u'goodvc78',
#    u'brunch']},
#  u'dexter85': {u'following': [u'tsp',
#    u'hoyoungchoi',
#    u'daeper',
#    u'goodvc78',
#    u'pelexus',
#    u'imagineer',
#    u'sabumbyun',
#    u'piux',
#    u'jaeholee',
#    u'jmh5531',
#    u'unitasbrand',
#    u'lifidea',
#    u'dengine',
#    u'mean1000',
#    u'freshcloud',
#    u'qncompany',
#    u'mobizenpekr',
#    u'intranet',
#    u'jihoonjeong',
#    u'yoojs8512',
#    u'brunch']},
#  u'digshock': {u'following': [u'lifidea',
#    u'vogue127',
#    u'captaink',
#    u'jimmyrim',
#    u'goodvc78',
#    u'insuk',
#    u'yper',
#    u'alden',
#    u'cleancode',
#    u'brunch']},
#  u'dohyeungkim': {u'following': [u'davidsr',
#    u'jounghoyoo',
#    u'rush1226',
#    u'lifidea',
#    u'goodvc78',
#    u'yoonash',
#    u'eunwoopark',
#    u'jaeyeonkim',
#    u'sooscape',
#    u'insuk',
#    u'suyoung',
#    u'mobizenpekr',
#    u'socialinnovator',
#    u'jihoonjeong',
#    u'promise4u',
#    u'yunjungseo',
#    u'sophie89',
#    u'brunch']},
#  u'dojinko': {u'following': [u'doberman',
#    u'tsp',
#    u'goodvc78',
#    u'dbr',
#    u'ashitaka',
#    u'dexter',
#    u'melanellie',
#    u'platina02',
#    u'joshkwon',
#    u'knockknock',
#    u'hitchwill',
#    u'manya',
#    u'aboutheman',
#    u'haneulalice',
#    u'jinkieun',
#    u'promise4u',
#    u'cjphynmu',
#    u'jigjang',
#    u'genie7pe',
#    u'sapu0000',
#    u'brunchflgu',
#    u'suomi',
#    u'bo0',
#    u'yoonash',
#    u'wjchee',
#    u'nitro2red',
#    u'yoojs8512',
#    u'head77x',
#    u'nergul01',
#    u'suhanjang',
#    u'brunch']},
#  u'dongchimi': {u'following': [u'internomago',
#    u'goodvc78',
#    u'insuk',
#    u'mitmle',
#    u'pubjinson',
#    u'cleancode',
#    u'kkan',
#    u'yaeegi',
#    u'daljasee',
#    u'minam']},
#  u'edgarbosungkim': {u'following': [u'goodvc78', u'manya', u'brunch']},
#  u'eunjiniyaaaa': {u'following': [u'cinehvwm',
#    u'musiroom',
#    u'goodvc78',
#    u'pigs',
#    u'brunch']},
#  u'exynos3': {u'following': [u'steven',
#    u'jwj0416',
#    u'choikop',
#    u'cellistshoo',
#    u'eomtank',
#    u'nim2mei9l3',
#    u'internomago',
#    u'parcchanyong',
#    u'elara1020',
#    u'delight412',
#    u'dndb21',
#    u'koreajb',
#    u'leesempre',
#    u'kjbsy',
#    u'thick99',
#    u'sensee',
#    u'bookdb',
#    u'jigjang',
#    u'saint0565',
#    u'fermata',
#    u'joonomics',
#    u'chyes',
#    u'zagmaster',
#    u'hstyle84',
#    u'whitequeen',
#    u'artincity',
#    u'birlzip',
#    u'realhoo',
#    u'2kija',
#    u'goodvc78',
#    u'pelexus',
#    u'rexsoma0901',
#    u'kazuma',
#    u'y-sean',
#    u'naymore',
#    u'guitarohyyy',
#    u'jigunamja',
#    u'socooleun',
#    u'jaeseungmun',
#    u'takk',
#    u'npulen',
#    u'ingcca',
#    u'goodbyepain',
#    u'creativejuwon',
#    u'futurewave',
#    u'sabumbyun',
#    u'editorialbe',
#    u'shoostory',
#    u'readingnomad',
#    u'iyagikot',
#    u'wikitree',
#    u'hyunhochu',
#    u'dronestarting',
#    u'aghermes',
#    u'quane',
#    u'water-dragon',
#    u'chaeminc',
#    u'aboutheman',
#    u'thisisjieun',
#    u'plusclov',
#    u'jungkwon-ahn',
#    u'95kimik',
#    u'youngryulch',
#    u'emor',
#    u'brunchsbqh',
#    u'hitchwill',
#    u'jobhelping',
#    u'sinji27',
#    u'hyewonable',
#    u'february',
#    u'sshong',
#    u'minieetea',
#    u'botongmarketer',
#    u'jimmyrim',
#    u'brunchflgu',
#    u'philosophus',
#    u'deckey1985',
#    u'breakthrough',
#    u'brunchizh0',
#    u'qsfamily',
#    u'quietgogo',
#    u'paper',
#    u'yoojs8512',
#    u'bwcho75',
#    u'mitpiki',
#    u'mobiinside',
#    u'jeffpaik',
#    u'techsuda',
#    u'starskylight',
#    u'arambaek',
#    u'yonghheo',
#    u'yulyul',
#    u'leaven',
#    u'bang1999',
#    u'hesse24',
#    u'zip',
#    u'indilab',
#    u'suhanjang',
#    u'moonskjc',
#    u'yper',
#    u'futureagent',
#    u'blade31',
#    u'team-slogup',
#    u'matt',
#    u'tsp',
#    u'lifidea',
#    u'jinhyunpark',
#    u'symriro',
#    u'jhwhjn',
#    u'insuk',
#    u'brunch']},
#  u'fivemin': {u'following': [u'imagineer',
#    u'2miho',
#    u'emor',
#    u'quane',
#    u'hangganread',
#    u'pubjinson',
#    u'brunchjqcb',
#    u'brunchflgu',
#    u'cats9030',
#    u'ibare',
#    u'creativejuwon',
#    u'memogekim',
#    u'sunghyunlim',
#    u'wipeshadow',
#    u'goodvc78',
#    u'minieetea',
#    u'sooscape',
#    u'mariapearl',
#    u'okmanp',
#    u'hika',
#    u'techus',
#    u'manya',
#    u'brunch4nrs',
#    u'editorialbe',
#    u'timotolkie',
#    u'insuk',
#    u'sophie89',
#    u'matt',
#    u'eunwoopark',
#    u'sclplus',
#    u'techhtml',
#    u'jsksoft',
#    u'futureagent',
#    u'syrljk12',
#    u'dalda',
#    u'daljasee',
#    u'papawolf',
#    u'perytail',
#    u'banglab',
#    u'suyoung',
#    u'jesin3',
#    u'kkang',
#    u'artmine',
#    u'yudong',
#    u'909090k',
#    u'tourister',
#    u'maumdal',
#    u'knockknock',
#    u'daddytt',
#    u'taebarii',
#    u'hyejinchoi',
#    u'lifidea',
#    u'2589000',
#    u'sapu0000',
#    u'plusclov',
#    u'rothem',
#    u'madvirus',
#    u'beautytech',
#    u'wjchee',
#    u'alden',
#    u'yongjinjinipln',
#    u'jaeseungmun',
#    u'michellekim',
#    u'genie7pe',
#    u'kisin',
#    u'iammento',
#    u'sshong',
#    u'cleancode',
#    u'annejeong',
#    u'chloelee',
#    u'manaka',
#    u'pxdstory',
#    u'starrystella']},
#  u'flatdesign': {u'following': [u'goodvc78',
#    u'pelexus',
#    u'pxdstory',
#    u'chataehyeon',
#    u'five0203',
#    u'meanimize',
#    u'promise4u',
#    u'jimmyrim',
#    u'lifidea',
#    u'marsnine',
#    u'jihoonjeong',
#    u'platina02',
#    u'mobiinside',
#    u'lainydays',
#    u'genie7pe',
#    u'myte',
#    u'suyoung',
#    u'jaeseungmun',
#    u'brunch1uhl',
#    u'eastgo',
#    u'brunch4nrs',
#    u'brunchk0qq',
#    u'yunjungseo',
#    u'sapu0000',
#    u'boramkim',
#    u'brunch']},
#  u'fritzkim': {u'following': [u'goodvc78',
#    u'insuk',
#    u'jihere1001',
#    u'yunjungseo',
#    u'mobizenpekr',
#    u'beautytech',
#    u'secondlyrics',
#    u'hancoma',
#    u'jihoonjeong',
#    u'brunch']},
#  u'gavin': {u'following': [u'kyeongwook-ma',
#    u'cayden',
#    u'arawn',
#    u'sangpom',
#    u'goodvc78',
#    u'hajunho',
#    u'dalda',
#    u'perytail',
#    u'breakthrough',
#    u'kwihun80',
#    u'aboutheman',
#    u'brunch']},
#  u'gettrend': {u'following': [u'goodvc78',
#    u'jimmyrim',
#    u'jade',
#    u'favorer',
#    u'dohyunkim',
#    u'ajmind',
#    u'jongsiksong',
#    u'brunchflgu',
#    u'brunch']},
#  u'geubin0414': {u'following': [u'hajunho',
#    u'davidsr',
#    u'robertlee',
#    u'hyeshik',
#    u'jamess',
#    u'realhoo',
#    u'pelexus',
#    u'goodvc78',
#    u'ethobisx',
#    u'hika',
#    u'imagineer',
#    u'sunghyunlim',
#    u'ohjongin',
#    u'ibare',
#    u'hyosha',
#    u'cordiallys',
#    u'pubjinson',
#    u'techhtml',
#    u'mobiinside',
#    u'nachoclub',
#    u'insuk',
#    u'eunwoopark',
#    u'lifidea',
#    u'hangganread',
#    u'breezynodul',
#    u'frooooogy',
#    u'favorer',
#    u'youngwungkim',
#    u'gokeshi',
#    u'myungjae7',
#    u'bwcho75',
#    u'iamquadr',
#    u'itsooda',
#    u'techsuda',
#    u'newsquare',
#    u'meanimize',
#    u'speedlyh',
#    u'ssin23',
#    u'nuribit',
#    u'sooscape',
#    u'iliyard',
#    u'platum',
#    u'ryon',
#    u'haneulalice',
#    u'sos',
#    u'civil',
#    u'cloud09',
#    u'hope-stone',
#    u'flatdesign',
#    u'yunjungseo',
#    u'joohoonjake',
#    u'mushman',
#    u'minsangchoi',
#    u'jeffpaik',
#    u'refreshstudio',
#    u'jowlee',
#    u'five0203',
#    u'sanghoonpak',
#    u'jungkloo',
#    u'jihere1001',
#    u'manya',
#    u'aboutheman',
#    u'skpman',
#    u'suyoung',
#    u'gr8idea',
#    u'bang1999',
#    u'piux',
#    u'captaink',
#    u'seiweb',
#    u'dohyunkim',
#    u'breakthrough',
#    u'hmin0606',
#    u'jungkwon-ahn',
#    u'chataehyeon',
#    u'jmh5531',
#    u'choikop',
#    u'kkonal',
#    u'jounghoyoo',
#    u'jimmyrim',
#    u'jongsiksong',
#    u'sophie89',
#    u'wadizhib',
#    u'promise4u',
#    u'sapu0000',
#    u'2589000',
#    u'genie7pe',
#    u'mobizenpekr',
#    u'jaeseungmun',
#    u'shimgun',
#    u'yoonash',
#    u'neovis',
#    u'wjchee',
#    u'gisoopa',
#    u'beautytech',
#    u'marsnine',
#    u'ajmind',
#    u'alden',
#    u'head77x',
#    u'borashow',
#    u'gamenext',
#    u'jade',
#    u'suhanjang',
#    u'ladyjeju',
#    u'iammento',
#    u'gfsaham',
#    u'binjis',
#    u'keymanjc',
#    u'minieetea',
#    u'cleancode',
#    u'sclplus',
#    u'nanta23',
#    u'dooilkim',
#    u'klaus',
#    u'jihoonjeong',
#    u'madvirus',
#    u'iffu',
#    u'yongjinjinipln',
#    u'pxdstory',
#    u'brunchlftm',
#    u'yoojs8512',
#    u'jigjang']},
#  u'gnsehtl': {u'following': [u'sclplus',
#    u'goodvc78',
#    u'brunchjqcb',
#    u'sooscape',
#    u'ilwoncoach',
#    u'yunjungseo',
#    u'yongjinjinipln',
#    u'jowlee',
#    u'brunch']},
#  u'gskyeong': {u'following': [u'goodvc78',
#    u'insuk',
#    u'havaqquq',
#    u'8percent',
#    u'futureagent',
#    u'sunnysideup',
#    u'brunch4nrs',
#    u'brunchflgu',
#    u'goodman1235',
#    u'madder',
#    u'easygo',
#    u'lifidea',
#    u'haneulalice',
#    u'brunch']},
#  u'gudokim': {u'following': [u'eomtank',
#    u'pelexus',
#    u'goodvc78',
#    u'xianglai',
#    u'jimmyrim',
#    u'marsnine',
#    u'yoojs8512',
#    u'breakthrough',
#    u'lifidea',
#    u'promise4u',
#    u'song720',
#    u'yper',
#    u'nohitall',
#    u'jihoonjeong']},
#  u'haaagood': {u'following': [u'goodvc78',
#    u'missingmay',
#    u'sooscape',
#    u'minieetea',
#    u'yunjungseo',
#    u'suyoung',
#    u'jimmyrim',
#    u'breakthrough',
#    u'jungkloo',
#    u'lifidea',
#    u'brunch']},
#  u'hanyong': {u'following': [u'tsp',
#    u'pangol75',
#    u'emor',
#    u'imagineer',
#    u'cloud09',
#    u'minieetea',
#    u'mobiinside',
#    u'sabumbyun',
#    u'goodvc78',
#    u'gokeshi',
#    u'jaeholee',
#    u'funder2000',
#    u'brunchflgu',
#    u'hyosha',
#    u'manya',
#    u'sooscape',
#    u'speedlyh',
#    u'yunjungseo',
#    u'meanimize',
#    u'2kija',
#    u'zagmaster',
#    u'sapu0000',
#    u'youngwungkim',
#    u'yongjinjinipln',
#    u'flatdesign',
#    u'jihere1001',
#    u'refreshstudio',
#    u'suyoung',
#    u'dol74',
#    u'joohoonjake',
#    u'brunch4nrs',
#    u'mygirl2797',
#    u'yoojs8512',
#    u'brunchuve5',
#    u'skysabre',
#    u'jimmyrim',
#    u'hmin0606',
#    u'juneleerk9b',
#    u'jinkieun',
#    u'socialinnovator',
#    u'lifidea',
#    u'bo0',
#    u'pxdstory',
#    u'brunch']},
#  u'henryhuh': {u'following': [u'goodvc78', u'indilab', u'brunch']},
#  u'hjkds0105': {u'following': [u'brunchflgu',
#    u'goodvc78',
#    u'aboutheman',
#    u'insuk',
#    u'sophie89',
#    u'jeremyyeun',
#    u'futureagent',
#    u'yannheo',
#    u'suyoung',
#    u'jsksoft']},
#  u'hmin0606': {u'following': [u'goodvc78',
#    u'jiwoongnet',
#    u'brunch7dpc',
#    u'pxdstory',
#    u'speedlyh',
#    u'yunjungseo',
#    u'suyoung',
#    u'meanimize',
#    u'five0203',
#    u'sapu0000',
#    u'jino',
#    u'haneulalice',
#    u'wanleehani',
#    u'sean',
#    u'lifidea',
#    u'sooscape',
#    u'jihere1001',
#    u'yoojs8512',
#    u'myungsunkim',
#    u'yongjinjinipln',
#    u'jimmyrim',
#    u'heejeong081',
#    u'conamss',
#    u'brunch']},
#  u'honggun008': {u'following': [u'goodvc78', u'brunch']},
#  u'hosangjeon': {u'following': [u'goodvc78', u'pelexus', u'brunch']},
#  u'hottel': {u'following': [u'goodvc78', u'brunch']},
#  u'hugeman': {u'following': [u'goodvc78', u'bwcho75', u'jsksoft', u'brunch']},
#  u'hyejinrnaf': {u'following': [u'goodvc78', u'brunchflgu', u'brunch']},
#  u'hyunmismtw': {u'following': [u'myte',
#    u'bwcho75',
#    u'yonghheo',
#    u'insuk',
#    u'goodvc78',
#    u'lifidea',
#    u'imagineer',
#    u'cojette',
#    u'aidenswmo',
#    u'brunch']},
#  u'i7tree': {u'following': [u'jinsoo1eas',
#    u'dukelung',
#    u'pelexus',
#    u'goodvc78',
#    u'manya',
#    u'jsksoft',
#    u'itsooda',
#    u'chaeminc',
#    u'wanleehani',
#    u'yoojs8512',
#    u'breakthrough',
#    u'ajmind',
#    u'haneulalice',
#    u'sclplus',
#    u'hmin0606',
#    u'brunchrd3j',
#    u'brunchflgu',
#    u'suhanjang',
#    u'brunch']},
#  u'ida0724': {u'following': [u'awsomeobig',
#    u'goodvc78',
#    u'pilseonjun',
#    u'sunsutu',
#    u'dalda',
#    u'seunghyukgo',
#    u'fromairplane',
#    u'juikkim',
#    u'chancalli',
#    u'bambyul',
#    u'fscloud',
#    u'20timeline',
#    u'alden',
#    u'prayise',
#    u'yujunsang',
#    u'yangsungmin',
#    u'leenouy',
#    u'sadrove',
#    u'jimin',
#    u'hakduri',
#    u'studiosagigoon',
#    u'psspsshi',
#    u'cloud',
#    u'courbet',
#    u'rothem',
#    u'diem',
#    u'brunch',
#    u'lonelyplanet',
#    u'hcyoon',
#    u'thecommaa']},
#  u'idoun21htbb': {u'following': [u'goodvc78', u'madvirus', u'brunch']},
#  u'image2man': {u'following': [u'goodvc78', u'brunch']},
#  u'imagineer': {u'following': [u'goodvc78',
#    u'lifidea',
#    u'sapu0000',
#    u'genie7pe',
#    u'haneulalice',
#    u'yoonash',
#    u'pelexus',
#    u'yper',
#    u'dobedobedo',
#    u'techhtml',
#    u'insuk',
#    u'ilwoncoach',
#    u'jmh5531',
#    u'romanticgrey',
#    u'yonghheo',
#    u'bwcho75',
#    u'seunghojung',
#    u'brunchlftm',
#    u'myte',
#    u'seattle',
#    u'brunch4nrs',
#    u'suhanjang',
#    u'codepink',
#    u'brunch']},
#  u'jaeyeonkim': {u'following': [u'goodvc78',
#    u'thebetterday',
#    u'datasciencedude',
#    u'ngelmaum',
#    u'zip',
#    u'suyoung',
#    u'youngwungkim',
#    u'sclplus',
#    u'insuk',
#    u'techsuda',
#    u'jinyoungkimpgzt',
#    u'doberman',
#    u'cojette',
#    u'hojunkim',
#    u'cloud09',
#    u'ilwoncoach',
#    u'rothem',
#    u'creativety',
#    u'skpman',
#    u'yannheo',
#    u'lifidea',
#    u'jimmyrim',
#    u'dbr',
#    u'promise4u',
#    u'1yearholiday',
#    u'micamica199',
#    u'hope-stone',
#    u'iamquadr',
#    u'hackathon',
#    u'hmin0606',
#    u'jisuyang',
#    u'jihoonjeong',
#    u'kid',
#    u'brunch']},
#  u'jaeyongjang': {u'following': [u'goodvc78',
#    u'brunchflgu',
#    u'manya',
#    u'wjchee',
#    u'insuk',
#    u'suhanjang',
#    u'jsksoft',
#    u'jangnoah',
#    u'hojunna',
#    u'ihearyou']},
#  u'jakewpark': {u'following': [u'zhanghaochen',
#    u'haneulalice',
#    u'brunchflgu',
#    u'goodvc78',
#    u'jsksoft',
#    u'nanta23',
#    u'herosoob',
#    u'bookfit',
#    u'platum',
#    u'mobiinside',
#    u'yoojs8512',
#    u'youngwungkim',
#    u'datasciencedude',
#    u'chaibschaibs',
#    u'creativejuwon',
#    u'kty0613',
#    u'gisoopa',
#    u'cloud09',
#    u'brunch']},
#  u'jang8474': {u'following': [u'goodvc78',
#    u'madvirus',
#    u'cleancode',
#    u'myte',
#    u'suhanjang',
#    u'brunch']},
#  u'jasonson': {u'following': [u'goodvc78',
#    u'xianglai',
#    u'varo',
#    u'jmh5531',
#    u'yoojs8512',
#    u'brunchflgu',
#    u'creativety',
#    u'brunch']},
#  u'jeffreyjung': {u'following': [u'pelexus',
#    u'jamess',
#    u'brunchjqcb',
#    u'goodvc78',
#    u'jmh5531',
#    u'sooscape',
#    u'stillalive31',
#    u'wjchee',
#    u'sanghoonpak',
#    u'promise4u',
#    u'jowlee',
#    u'brunch4nrs',
#    u'aboutheman',
#    u'jaedi',
#    u'iliyard',
#    u'manya',
#    u'breakthrough',
#    u'soonkyujang',
#    u'yoonash',
#    u'dohyunkim',
#    u'marsnine',
#    u'ajmind',
#    u'yudong',
#    u'rothem',
#    u'kkonal',
#    u'head77x',
#    u'sshong',
#    u'suhanjang',
#    u'brunchflgu',
#    u'brunch']},
#  u'jeongdeoksu7n2z': {u'following': [u'goodvc78',
#    u'insuk',
#    u'wanleehani',
#    u'cleancode',
#    u'brunch']},
#  u'jeongsy10sqhn': {u'following': [u'sustainlife',
#    u'kjbsy',
#    u'yspecial',
#    u'goodvc78',
#    u'techsuda',
#    u'sabumbyun',
#    u'hoho5492',
#    u'brunchega3',
#    u'imagineer',
#    u'yonghheo',
#    u'msfkorea',
#    u'bookdb',
#    u'brunch']},
#  u'jephrix': {u'following': [u'sshong',
#    u'goodvc78',
#    u'hajunho',
#    u'yper',
#    u'head77x',
#    u'koreajb',
#    u'jamding',
#    u'arawn',
#    u'cailhuiris',
#    u'ibare',
#    u'manya',
#    u'alden',
#    u'techhtml',
#    u'yoonash',
#    u'insuk',
#    u'imagineer',
#    u'bwcho75',
#    u'ihearyou',
#    u'yannheo',
#    u'2691999',
#    u'vytlgud',
#    u'guxist',
#    u'yoonjikwon',
#    u'kkonal',
#    u'2kija',
#    u'cleancode',
#    u'jinkieun',
#    u'1yearholiday',
#    u'micamica199',
#    u'suhanjang',
#    u'romanticgrey',
#    u'tuburkis',
#    u'1100px',
#    u'whiteink',
#    u'lonelyplanet',
#    u'eastrain',
#    u'fromairplane',
#    u'brunch']},
#  u'jhbaek': {u'following': [u'goodvc78',
#    u'aidenswmo',
#    u'mobiinside',
#    u'five0203',
#    u'jihere1001',
#    u'meanimize',
#    u'speedlyh',
#    u'mushman',
#    u'suyoung',
#    u'wjchee',
#    u'swizzle',
#    u'pubjinson',
#    u'readmoney',
#    u'mila',
#    u'sapu0000',
#    u'joonomics',
#    u'lifidea',
#    u'genie7pe',
#    u'alden',
#    u'cli-annah',
#    u'sshong',
#    u'jimmyrim',
#    u'borashow',
#    u'suhanjang',
#    u'brunchlftm',
#    u'minieetea',
#    u'yeinz',
#    u'jejugrapher',
#    u'cleancode',
#    u'yoojs8512',
#    u'klaus',
#    u'archicwy',
#    u'goodbyepain',
#    u'lllshotlll',
#    u'iamquadr',
#    u'nitro2red',
#    u'jigjang']},
#  u'jinhakkim': {u'following': [u'sbcoba',
#    u'testude',
#    u'jaeyeonkim',
#    u'goodvc78',
#    u'sunsutu',
#    u'yonghheo',
#    u'haneulalice']},
#  u'jiyoung9z1p': {u'following': [u'goodvc78',
#    u'jimmyrim',
#    u'lifidea',
#    u'creativety',
#    u'jihoonjeong',
#    u'yoojs8512',
#    u'brunch']},
#  u'jjune0412': {u'following': [u'goodvc78', u'brunch']},
#  u'jmingyu': {u'following': [u'soldonii',
#    u'ehdwlsez4ge',
#    u'npulen',
#    u'zagmaster',
#    u'eastrain',
#    u'greenful',
#    u'goodvc78',
#    u'socooleun',
#    u'laughingbeans',
#    u'designdesign',
#    u'okaytina',
#    u'matryo',
#    u'jeremycho',
#    u'tuburkis',
#    u'liha',
#    u'cayden',
#    u'futurewave',
#    u'creativejuwon',
#    u'quane',
#    u'zip',
#    u'laurentiusj',
#    u'hachistory',
#    u'brunchega3',
#    u'sweetmeen',
#    u'kty0613',
#    u'peony',
#    u'rawandb',
#    u'syrljk12',
#    u'hyosha',
#    u'techsuda',
#    u'symriro',
#    u'homoartcus',
#    u'yoojs8512',
#    u'vytlgud',
#    u'mygirl2797',
#    u'seonyu10',
#    u'romanticgrey',
#    u'mystelee',
#    u'2kija',
#    u'sensee',
#    u'jhwhjn',
#    u'hmin0606',
#    u'yonghheo',
#    u'bwcho75',
#    u'yannheo',
#    u'leaven',
#    u'jaeholee',
#    u'prorange',
#    u'cojette',
#    u'sooscape',
#    u'speedlyh',
#    u'yunjungseo',
#    u'youngwungkim',
#    u'suyoung',
#    u'rats',
#    u'hajunho',
#    u'hancoma',
#    u'brunchk2h4',
#    u'leejaegoo',
#    u'meanimize',
#    u'five0203',
#    u'sterdam',
#    u'hojunna',
#    u'civil',
#    u'darakstory',
#    u'chataehyeon',
#    u'kangjak',
#    u'intranet',
#    u'kwihun80',
#    u'micamica199',
#    u'genie7pe',
#    u'shoostory',
#    u'jaeseungmun',
#    u'myte',
#    u'dbs1260023',
#    u'kangsunseng',
#    u'joyjun7',
#    u'minji1120',
#    u'joshkwon',
#    u'superdreamy',
#    u'ryuhyejin',
#    u'19-21p',
#    u'bohri1988',
#    u'reinia',
#    u'kamsungk',
#    u'korlang',
#    u'cloud09',
#    u'brunch']},
#  u'johanguk': {u'following': [u'goodvc78',
#    u'gfsaham',
#    u'mobiinside',
#    u'snowyn',
#    u'brunch']},
#  u'jslivane': {u'following': [u'goodvc78', u'brunch']},
#  u'jts87': {u'following': [u'goodvc78', u'imagineer', u'brunch']},
#  u'jungi': {u'following': [u'siliconroad',
#    u'yper',
#    u'pelexus',
#    u'koreajb',
#    u'iammento',
#    u'jeremycho',
#    u'socialmkt',
#    u'imagineer',
#    u'madvirus',
#    u'rothem',
#    u'jaydenkim',
#    u'brunchflgu',
#    u'kim432432',
#    u'zip',
#    u'botongmarketer',
#    u'youngwungkim',
#    u'datasciencedude',
#    u'aidenswmo',
#    u'jaeyeonkim',
#    u'95kimik',
#    u'jigjang',
#    u'eastgo',
#    u'blade31',
#    u'sshong',
#    u'zamong',
#    u'daddytt',
#    u'paper',
#    u'yoojs8512',
#    u'beautytech',
#    u'jeffpaik',
#    u'breakthrough',
#    u'matt',
#    u'minsangchoi',
#    u'lifidea',
#    u'yongjinjinipln',
#    u'son6336',
#    u'jimmyrim',
#    u'mitpiki',
#    u'bwcho75',
#    u'mobiinside',
#    u'techsuda',
#    u'goodvc78',
#    u'sshongnim',
#    u'arawn',
#    u'cleancode',
#    u'indilab',
#    u'insuk',
#    u'brunch']},
#  u'kanghyunjun': {u'following': [u'paige',
#    u'koreajb',
#    u'goodvc78',
#    u'haeegri',
#    u'wjchee',
#    u'cojette',
#    u'platum',
#    u'chaibschaibs',
#    u'mang',
#    u'kooning11',
#    u'intotibet',
#    u'lifidea',
#    u'hcyoon',
#    u'brunch3dsf',
#    u'hmin0606',
#    u'blade31',
#    u'cataglyphis',
#    u'yeonjikim',
#    u'pxdstory',
#    u'brunch']},
#  u'kihwanlee': {u'following': [u'goodvc78', u'brunch']},
#  u'kingmbc': {u'following': [u'goodvc78',
#    u'techhtml',
#    u'lifidea',
#    u'pelexus',
#    u'aidenswmo',
#    u'stevepark',
#    u'brunch4nrs',
#    u'insuk',
#    u'brunch']},
#  u'kk760105': {u'following': [u'goodvc78',
#    u'lifidea',
#    u'cojette',
#    u'cloud09',
#    u'joonomics',
#    u'glosh721',
#    u'ngelmaum',
#    u'brunch']},
#  u'kkchman': {u'following': [u'blackik',
#    u'doberman',
#    u'koreajb',
#    u'goodvc78',
#    u'pelexus',
#    u'hstyle84',
#    u'acgroup',
#    u'brunchflgu',
#    u'yoojs8512',
#    u'five0203',
#    u'manya',
#    u'flytosky1117',
#    u'brunch4nrs',
#    u'breakthrough',
#    u'sapu0000',
#    u'jimmyrim',
#    u'borashow',
#    u'brunchrd3j',
#    u'yoonash',
#    u'brunch']},
#  u'kodatt': {u'following': [u'stillalive31',
#    u'jinsoo1eas',
#    u'logostein',
#    u'hajunho',
#    u'comics119',
#    u'forsy20',
#    u'eejsung',
#    u'reconceptor',
#    u'kim432432',
#    u'chaibschaibs',
#    u'iyagikot',
#    u'tourism',
#    u'jupiter',
#    u'stevehan',
#    u'pelexus',
#    u'4u4u',
#    u'gahye',
#    u'ollein',
#    u'dalda',
#    u'madvirus',
#    u'two-tone',
#    u'cinehvwm',
#    u'awsomeobig',
#    u'goodvc78',
#    u'galleryd',
#    u'marupress',
#    u'quane',
#    u'sabumbyun',
#    u'delight412',
#    u'digh1231231',
#    u'yokurong',
#    u'aghermes',
#    u'ibare',
#    u'sunghyunlim',
#    u'kmin',
#    u'hstyle84',
#    u'vijay',
#    u'stevenh',
#    u'cpa1997',
#    u'starskylight',
#    u'deckey1985',
#    u'symriro',
#    u'sunnyluvin',
#    u'manya',
#    u'yulyul',
#    u'blade31',
#    u'eunwoopark',
#    u'writingo119',
#    u'romanticgrey',
#    u'pubjinson',
#    u'snowcountry',
#    u'arambaek',
#    u'neddaland',
#    u'suhanjang',
#    u'meanimize',
#    u'jnbells',
#    u'gangbaram',
#    u'yper',
#    u'kozzangnim',
#    u'jhwhjn',
#    u'taeheekim',
#    u'jaeseungmun',
#    u'mygirl2797',
#    u'cojette',
#    u'wo-motivator',
#    u'seokay85',
#    u'wherevermis',
#    u'bookdb',
#    u'exuvia',
#    u'xianglai',
#    u'cloud09',
#    u'bwcho75',
#    u'crisis-mgmt',
#    u'reading15m',
#    u'opri',
#    u'techsuda',
#    u'lumafonto',
#    u'mushman',
#    u'hanit',
#    u'mobizenpekr',
#    u'bh4848park',
#    u'futureagent',
#    u'syrljk12',
#    u'chauchau',
#    u'yannheo',
#    u'songjh03',
#    u'favorer',
#    u'jsksoft',
#    u'jinheepark6a8q',
#    u'head77x',
#    u'herosoob',
#    u'suyoung',
#    u'wirteforwrong',
#    u'mystelee',
#    u'2kija',
#    u'punk69',
#    u'raekim',
#    u'botongmarketer',
#    u'myungsunkim',
#    u'bpark',
#    u'bang1999',
#    u'mihyangeun',
#    u'sanghoonpak',
#    u'illumi33',
#    u'minsangchoi',
#    u'woody5718',
#    u'jay8zg0',
#    u'melanellie',
#    u'yoonjikwon',
#    u'heonil',
#    u'artmerchant',
#    u'micamica199',
#    u'platina02',
#    u'mobiinside',
#    u'sooscape',
#    u'five0203',
#    u'kimkwan',
#    u'funder2000',
#    u'wjchee',
#    u'knockknock',
#    u'flyjy724',
#    u'vivakakao',
#    u'yyanistory',
#    u'kkang',
#    u'editorialbe',
#    u'megaonic',
#    u'lainydays',
#    u'pinie',
#    u'shoostory',
#    u'brunchmpto',
#    u'jungkloo',
#    u'happyclown',
#    u'breakthrough',
#    u'sapu0000',
#    u'jaehojaeho',
#    u'joohoonjake',
#    u'mistyfriday',
#    u'digitaldreamer',
#    u'jejugrapher',
#    u'jinhyuklee',
#    u'prorange',
#    u'jongsiksong',
#    u'kooning11',
#    u'seiweb',
#    u'skpman',
#    u'hyejinchoi',
#    u'ecrireici',
#    u'onec',
#    u'chaeminc',
#    u'kwihun80',
#    u'sustainlife',
#    u'mumu',
#    u'choikop',
#    u'nanta23',
#    u'kangjak',
#    u'jeffpaik',
#    u'borashow',
#    u'jinkieun',
#    u'yooatic84',
#    u'saewookkangboy',
#    u'ajmind',
#    u'clinky85',
#    u'hosungsong',
#    u'ruby823',
#    u'lyju7479',
#    u'opencommz',
#    u'perytail',
#    u'dongkyoonno',
#    u'daljasee',
#    u'zagmaster',
#    u'909090k',
#    u'hope-stone',
#    u'sclplus',
#    u'song720',
#    u'iamquadr',
#    u'captaink',
#    u'eundang',
#    u'jimmyrim',
#    u'jmh5531',
#    u'sophie89',
#    u'dooilkim',
#    u'yoonash',
#    u'wadizhib',
#    u'lifidea',
#    u'ilwoncoach',
#    u'leaven',
#    u'genie7pe',
#    u'violetcloud',
#    u'promise4u',
#    u'rothem',
#    u'brunchflgu',
#    u'hmin0606',
#    u'sshong',
#    u'kisin',
#    u'yoojs8512',
#    u'channy',
#    u'brunch']},
#  u'kylef0im': {u'following': [u'goodvc78',
#    u'greenful',
#    u'jimmyrim',
#    u'iamquadr',
#    u'dobbyhan',
#    u'alden',
#    u'brunch']},
#  u'lastsky1982': {u'following': [u'brunchflgu',
#    u'brunch',
#    u'goodvc78',
#    u'lifidea']},
#  u'leehs1017': {u'following': [u'pelexus',
#    u'insuk',
#    u'brunchlftm',
#    u'brunch4nrs',
#    u'goodvc78',
#    u'madvirus',
#    u'jcsla',
#    u'hajunho',
#    u'hika',
#    u'wjchee',
#    u'yoojs8512',
#    u'mobiinside',
#    u'techhtml',
#    u'madchick',
#    u'myungjae7',
#    u'klaus',
#    u'kyeongwook-ma',
#    u'arawn',
#    u'cleancode',
#    u'brunch']},
#  u'letsgo90': {u'following': [u'sos',
#    u'goodvc78',
#    u'aidenswmo',
#    u'mistyfriday',
#    u'insuk',
#    u'breakthrough',
#    u'techsuda',
#    u'jimmyrim',
#    u'mygirl2797',
#    u'vijay',
#    u'haneulalice',
#    u'kwihun80',
#    u'yoonash',
#    u'bo0',
#    u'brunch']},
#  u'lifidea': {u'following': [u'eomtank',
#    u'pelexus',
#    u'yper',
#    u'ingcca',
#    u'jaeyeonkim',
#    u'cindyboramlee',
#    u'4u4u',
#    u'koreajb',
#    u'hstyle84',
#    u'captaink',
#    u'groovetube',
#    u'wonish',
#    u'jirehhouse',
#    u'goodvc78',
#    u'herosoob',
#    u'tennistory',
#    u'vijay',
#    u'brunchjnux',
#    u'zone',
#    u'babydiary',
#    u'mygirl2797',
#    u'monofive55',
#    u'chaibschaibs',
#    u'makersgonnamake',
#    u'gungs',
#    u'20timeline',
#    u'pletalk',
#    u'yggdrasil',
#    u'insuk',
#    u'seattle',
#    u'joohoonjake',
#    u'cafesmith',
#    u'jinju32',
#    u'jsksoft',
#    u'davidyoon',
#    u'cloud09',
#    u'gogamza',
#    u'brunch6tjq',
#    u'wherevermis',
#    u'yonghheo',
#    u'ollein',
#    u'homoartcus',
#    u'amyyoungah',
#    u'parcchanyong',
#    u'meanimize',
#    u'hyejinchoi',
#    u'violetcloud',
#    u'borashow',
#    u'loveinsight',
#    u'testude',
#    u'xenix',
#    u'jmh5531',
#    u'shoostory',
#    u'ngelmaum',
#    u'seungwanhon',
#    u'steven',
#    u'hoonyqqq',
#    u'brunchdhqp',
#    u'aboutheman',
#    u'thecommaa',
#    u'yujunsang',
#    u'brunchk0qq',
#    u'lllshotlll',
#    u'stopfornow',
#    u'documenticle',
#    u'nyfashionbiz',
#    u'sonasona',
#    u'vogue127',
#    u'dooholee',
#    u'prorange',
#    u'bookdb',
#    u'dalmoon',
#    u'peterpens',
#    u'stevenyoo',
#    u'seiweb',
#    u'roseroad',
#    u'kne',
#    u'sunnysideup',
#    u'hannapark',
#    u'blade31',
#    u'todayfootball',
#    u'mrkwondo',
#    u'najakaya',
#    u'yooatic84',
#    u'kwihun80',
#    u'soyoungkim',
#    u'jinnyjieunk',
#    u'jaeseungmun',
#    u'jinkieun',
#    u'skpman',
#    u'scape',
#    u'uincity',
#    u'kangjak',
#    u'csj3814',
#    u'civil',
#    u'jejugrapher',
#    u'mila',
#    u'hmin0606',
#    u'brunchflgu',
#    u'jungyoon',
#    u'yeinz',
#    u'chataehyeon',
#    u'sanghwasong',
#    u'sustainlife',
#    u'hope-stone',
#    u'promise4u',
#    u'haneulalice',
#    u'foodenjoy',
#    u'909090k',
#    u'breakthrough',
#    u'ihearyou',
#    u'beatto',
#    u'gamenext',
#    u'sangwonsuh',
#    u'1yearholiday',
#    u'daljasee',
#    u'ckjung',
#    u'starskylight',
#    u'opri',
#    u'yeunni2',
#    u'gayoungpark',
#    u'guxist',
#    u'jumankim',
#    u'lonelyplanet',
#    u'shixicheng',
#    u'minsangchoi',
#    u'jihoonjeong',
#    u'cvision33',
#    u'cli-annah',
#    u'shala',
#    u'choikyunghe',
#    u'matthew-chang',
#    u'jongsiksong',
#    u'jangnoah',
#    u'taebarii',
#    u'bo0',
#    u'kkang',
#    u'tschoe56',
#    u'eastgo',
#    u'tourister',
#    u'yoonash',
#    u'piux',
#    u'marsnine',
#    u'2kija',
#    u'yyja',
#    u'1000ml',
#    u'dsunbee',
#    u'rothem',
#    u'5345341',
#    u'cojette',
#    u'fromairplane',
#    u'brunchxecm',
#    u'meca',
#    u'dol74',
#    u'artmerchant',
#    u'goodman1235',
#    u'myungjae7',
#    u'mobiinside',
#    u'wjchee',
#    u'glosh721',
#    u'siliconroad',
#    u'sadrove',
#    u'krazyeom',
#    u'dsuh',
#    u'gisoopa',
#    u'funder2000',
#    u'mixcoffee',
#    u'joonomics',
#    u'son6336',
#    u'suyoung',
#    u'reading15m',
#    u'soonkyujang',
#    u'missingmay',
#    u'myte',
#    u'myungjinjun',
#    u'sophie89',
#    u'yongjinjinipln',
#    u'binjis',
#    u'95kimik',
#    u'youngwungkim',
#    u'wadizhib',
#    u'jbbae',
#    u'micamica199',
#    u'hyunkimkr',
#    u'madlymissyou',
#    u'donothing',
#    u'yoojs8512',
#    u'suhanjang',
#    u'hogeunyum',
#    u'sshong',
#    u'brunch']},
#  u'lightandsalt74': {u'following': [u'goodvc78',
#    u'imagineer',
#    u'eomtank',
#    u'cojette',
#    u'lifidea',
#    u'roasterkay',
#    u'hajunho',
#    u'pubjinson',
#    u'sunghyunlim',
#    u'ibare']},
#  u'lobojeong': {u'following': [u'younghojeon',
#    u'daljasee',
#    u'mr-kim',
#    u'yoojs8512',
#    u'tsp',
#    u'sangpom',
#    u'eunwoopark',
#    u'wadizhib',
#    u'goodvc78',
#    u'jimmyrim',
#    u'datasciencedude',
#    u'brunchv0py',
#    u'dengine',
#    u'jinhyunpark',
#    u'mobiinside',
#    u'alleciel',
#    u'redman1005',
#    u'yoonash',
#    u'slowmagazine',
#    u'brunch',
#    u'illumi33',
#    u'unitasbrand']},
#  u'mammloveliyf': {u'following': [u'mistyfriday',
#    u'zagmaster',
#    u'stevehan',
#    u'raekim',
#    u'flyjy724',
#    u'silsill',
#    u'goodvc78',
#    u'rothem',
#    u'captaink',
#    u'ethnographer',
#    u'cinehvwm',
#    u'yourboyhood',
#    u'awsomeobig',
#    u'kooning11',
#    u'brunch']},
#  u'marantz': {u'following': [u'goodvc78',
#    u'handend',
#    u'minieetea',
#    u'exuvia',
#    u'brunch']},
#  u'matthewjeong': {u'following': [u'goodvc78', u'brunch']},
#  u'minwoohong': {u'following': [u'cojette',
#    u'goodvc78',
#    u'lifidea',
#    u'yoojs8512',
#    u'sclplus',
#    u'brunchflgu']},
#  u'moragoyo': {u'following': [u'goodvc78', u'brunch']},
#  u'nullz': {u'following': [u'ingcca',
#    u'lifidea',
#    u'koreajb',
#    u'goodvc78',
#    u'sooscape',
#    u'ollein',
#    u'onec',
#    u'myte',
#    u'jimmyrim',
#    u'petersohn']},
#  u'oscary96u': {u'following': [u'starskylight',
#    u'sundog',
#    u'goodvc78',
#    u'ondisplay',
#    u'brunch']},
#  u'paranoeac': {u'following': [u'seojoon',
#    u'goodvc78',
#    u'yper',
#    u'roasterkay',
#    u'insuk',
#    u'sunsutu',
#    u'brunch']},
#  u'pomp0000': {u'following': [u'aidenswmo',
#    u'jaeyeonkim',
#    u'goodvc78',
#    u'cojette',
#    u'cloud09',
#    u'platum',
#    u'mushman',
#    u'jade',
#    u'ipuris',
#    u'ngelmaum',
#    u'brunch4nrs',
#    u'futureshaper',
#    u'1yearholiday',
#    u'promise4u',
#    u'breakthrough',
#    u'dohyunkim',
#    u'stevepark',
#    u'pauljangnyz2',
#    u'genie7pe',
#    u'lifidea',
#    u'yoonash',
#    u'sophie89',
#    u'sshong',
#    u'suhanjang',
#    u'jimmyrim',
#    u'brunchlftm',
#    u'oeoechoi',
#    u'95kimik',
#    u'youngwungkim',
#    u'wadizhib',
#    u'glosh721',
#    u'yongjinjinipln',
#    u'binjis',
#    u'brunch']},
#  u'rainfk': {u'following': [u'goodvc78', u'95kimik', u'brunch']},
#  u'reading15m': {u'following': [u'goodvc78',
#    u'davidsr',
#    u'hyunjaelee',
#    u'aidenswmo',
#    u'brunchjqcb',
#    u'hyejinchoi',
#    u'jade',
#    u'futureagent',
#    u'yoojs8512',
#    u'aboutheman',
#    u'2kija',
#    u'manya',
#    u'verdesox',
#    u'soongyuahn',
#    u'funder2000',
#    u'chaeminc',
#    u'kimsophia57',
#    u'sshong',
#    u'keymanjc',
#    u'thebookman',
#    u'seoulgrandma',
#    u'sophie89',
#    u'leenouy',
#    u'blade31',
#    u'brunch']},
#  u'redieon': {u'following': [u'imagineer',
#    u'suhanjang',
#    u'goodvc78',
#    u'banghaklife',
#    u'brunchrl8a',
#    u'funder2000',
#    u'gfsaham',
#    u'brunchlftm',
#    u'cong',
#    u'daljasee',
#    u'brunch']},
#  u'ring801112': {u'following': [u'lifidea', u'goodvc78', u'brunch']},
#  u'romad61an': {u'following': [u'goodvc78',
#    u'klaus',
#    u'borashow',
#    u'yannheo',
#    u'lifidea',
#    u'brunchflgu',
#    u'brunch']},
#  u'seongwoonse': {u'following': [u'yper',
#    u'thebetterday',
#    u'vijay',
#    u'goodvc78',
#    u'techsuda',
#    u'tsp',
#    u'datasciencedude',
#    u'wing365',
#    u'gundigi',
#    u'jodongin']},
#  u'sooen90': {u'following': [u'goodvc78',
#    u'pelexus',
#    u'yper',
#    u'skyscanner',
#    u'sunsutu',
#    u'imagineer',
#    u'neddaland',
#    u'goodbyepain',
#    u'cloud',
#    u'sadrove',
#    u'techhtml',
#    u'acet',
#    u'cojette',
#    u'lifidea',
#    u'breakthrough',
#    u'insuk',
#    u'bh4848park',
#    u'cleancode',
#    u'wherevermis',
#    u'savvynoh',
#    u'lonelyplanet',
#    u'csco2pw2gt',
#    u'herenthere',
#    u'dohyunkim',
#    u'lucykey',
#    u'lainydays',
#    u'jinmuk',
#    u'cloud09',
#    u'dono',
#    u'son6336',
#    u'tomnterri',
#    u'ryanmoon83',
#    u'doubleshot',
#    u'amber',
#    u'stevepark',
#    u'myte',
#    u'matthew-chang',
#    u'chaechae',
#    u'brunch4nrs',
#    u'brunch']},
#  u'sooyoungpark': {u'following': [u'goodvc78',
#    u'cleancode',
#    u'arawn',
#    u'brunch']},
#  u'spinoza79': {u'following': [u'goodvc78',
#    u'brunch6tjq',
#    u'ihearyou',
#    u'gomtaewoo',
#    u'ansyd',
#    u'camomile',
#    u'intranet',
#    u'snowcountry',
#    u'artmerchant',
#    u'brunch']},
#  u'stanley': {u'following': [u'goodvc78',
#    u'suyoung',
#    u'sapu0000',
#    u'haneulalice',
#    u'meca',
#    u'myte',
#    u'jihoonjeong',
#    u'madvirus',
#    u'brunchk0qq',
#    u'shala',
#    u'boramkim',
#    u'wjchee',
#    u'yongjinjinipln',
#    u'jsksoft',
#    u'mobiinside',
#    u'nachoclub',
#    u'lifidea',
#    u'yoojs8512',
#    u'jimmyrim',
#    u'brunch']},
#  u'studioho6': {u'following': [u'goodvc78', u'camlost', u'brunch']},
#  u'sufeel97': {u'following': [u'sensee',
#    u'gahye',
#    u'goodvc78',
#    u'zip',
#    u'silvermouse',
#    u'starskylight',
#    u'raekim',
#    u'bookdb',
#    u'yonghheo',
#    u'sustainlife',
#    u'herosoob',
#    u'jsksoft',
#    u'bang1999',
#    u'hoho5492',
#    u'connieworld',
#    u'plusclov',
#    u'tcatkr',
#    u'pjh5101',
#    u'beat',
#    u'maumdal',
#    u'makecake',
#    u'analog',
#    u'snim83',
#    u'greenpeacekorea',
#    u'wjchee',
#    u'guxist',
#    u'tschoe56',
#    u'eonr123',
#    u'suyoung',
#    u'brunch4nrs',
#    u'borashow',
#    u'rats',
#    u'happyjisu',
#    u'hesse24',
#    u'sunnysideup',
#    u'baka',
#    u'aboutheman',
#    u'promise4u',
#    u'haneulalice',
#    u'dohyunkim',
#    u'1100px',
#    u'opri',
#    u'1yearholiday',
#    u'yoonash',
#    u'jimmyrim',
#    u'sterdam',
#    u'funder2000',
#    u'ihearyou',
#    u'sophie89',
#    u'soleillove',
#    u'rothem',
#    u'joonomics',
#    u'sapu0000',
#    u'2589000',
#    u'brunchrd3j',
#    u'sshong',
#    u'astonut',
#    u'jaeseungmun',
#    u'yudong',
#    u'mean1000',
#    u'bookgom',
#    u'chancalli',
#    u'onec',
#    u'ilwoncoach',
#    u'yoonjikwon',
#    u'dbr',
#    u'gisoopa',
#    u'clinky85',
#    u'yoojs8512',
#    u'toyprince',
#    u'hosungsong',
#    u'jihoonjeong',
#    u'aracho',
#    u'phoebescafe',
#    u'cli-annah',
#    u'hancoma',
#    u'jaedi',
#    u'brunchlftm',
#    u'honalove',
#    u'mygirl2797',
#    u'iamquadr',
#    u'keymanjc',
#    u'mila',
#    u'esther220',
#    u'10x4',
#    u'brunchflgu',
#    u'sooscape',
#    u'pinie',
#    u'wonish',
#    u'dalda',
#    u'kkang',
#    u'hitchwill',
#    u'oeoechoi',
#    u'piux',
#    u'chojeremy',
#    u'rainbowbaby',
#    u'jimin',
#    u'ourlove',
#    u'suhanjang',
#    u'eujinnhong',
#    u'flytosky1117',
#    u'yoon',
#    u'papa',
#    u'jinkieun',
#    u'perytail',
#    u'brunch']},
#  u'sybae0306': {u'following': [u'goodvc78',
#    u'miric',
#    u'brunchjqcb',
#    u'creativejuwon',
#    u'hstyle84',
#    u'zip',
#    u'brunchflgu',
#    u'lucidfall',
#    u'raekim',
#    u'silvermouse']},
#  u'taekyungkim': {u'following': [u'davidsr',
#    u'kkang',
#    u'neddaland',
#    u'daljasee',
#    u'yeunsookim',
#    u'mr-kim',
#    u'futureagent',
#    u'pelexus',
#    u'goodvc78',
#    u'snowyn',
#    u'brunch27uc',
#    u'roh222',
#    u'creativity',
#    u'mobiinside',
#    u'funfunhan',
#    u'nachoclub',
#    u'arambaek',
#    u'jmh5531',
#    u'jigjang',
#    u'jaeholee',
#    u'myungjae7',
#    u'jaeunyun',
#    u'genie7pe',
#    u'booktopia',
#    u'jinkieun',
#    u'jsksoft',
#    u'jade',
#    u'mobizenpekr',
#    u'platina02',
#    u'jaydenkim',
#    u'suhanjang',
#    u'wanleehani',
#    u'2kija',
#    u'yey1118',
#    u'kkonal',
#    u'prorange',
#    u'chaeminc',
#    u'jowlee',
#    u'aboutheman',
#    u'haneulalice',
#    u'kozzangnim',
#    u'mean1000',
#    u'suomi',
#    u'ilwoncoach',
#    u'ajmind',
#    u'jaedi',
#    u'taehoyoon',
#    u'bowae',
#    u'promise4u',
#    u'micamica199',
#    u'choikop',
#    u'sclplus',
#    u'breakthrough',
#    u'jimmyrim',
#    u'yoonash',
#    u'artmerchant',
#    u'jihoonjeong',
#    u'jaeseungmun',
#    u'iwmind',
#    u'yoojs8512',
#    u'nanta23',
#    u'keymanjc',
#    u'jino',
#    u'brunchlftm',
#    u'brunchflgu',
#    u'sshong',
#    u'brunch']},
#  u'thnku': {u'following': [u'socialinnovator',
#    u'quane',
#    u'sooscape',
#    u'goodvc78',
#    u'mitpiki',
#    u'jaeholee',
#    u'hyosha',
#    u'piux',
#    u'jihoonjeong',
#    u'wjchee',
#    u'techsuda',
#    u'hmin0606',
#    u'yunjungseo',
#    u'manya',
#    u'lifidea',
#    u'suyoung',
#    u'ilwoncoach',
#    u'haneulalice',
#    u'soonkyujang',
#    u'1yearholiday',
#    u'sclplus',
#    u'nanta23',
#    u'speedlyh',
#    u'brunch']},
#  u'vins103': {u'following': [u'eunwoopark',
#    u'sendbird',
#    u'goodvc78',
#    u'cleancode',
#    u'brunchlftm',
#    u'brunch']},
#  u'vista4336': {u'following': [u'head77x',
#    u'ymoon',
#    u'leesempre',
#    u'mitpiki',
#    u'pelexus',
#    u'goodvc78',
#    u'hstyle84',
#    u'shinseungkeon',
#    u'jaeseungmun',
#    u'nonayo',
#    u'awsomeobig',
#    u'acgroup',
#    u'brunchjqcb',
#    u'brunch']},
#  u'wanghyosun': {u'following': [u'goodvc78',
#    u'gr8idea',
#    u'refreshstudio',
#    u'yunjungseo',
#    u'hmin0606',
#    u'meanimize',
#    u'sooscape',
#    u'sterdam',
#    u'suyoung',
#    u'jimmyrim',
#    u'brunch']},
#  u'water-dragon': {u'following': [u'goodvc78',
#    u'brunchg5op',
#    u'coudinky',
#    u'shoostory',
#    u'chory1004',
#    u'sssp0112',
#    u'dstory',
#    u'neddaland',
#    u'apple314159',
#    u'february',
#    u'coloresprit',
#    u'visionholic',
#    u'thisisjieun',
#    u'juhan3',
#    u'missj1227',
#    u'captaindrop',
#    u'brunchizxo',
#    u'zzanna87',
#    u'cjmjmbest',
#    u'sonnabi89',
#    u'joanne0618',
#    u'happinessforkm',
#    u'byetom',
#    u'light-shin0201',
#    u'megaonic',
#    u'ssay-lee',
#    u'treesky',
#    u'hachistory',
#    u'janejeehyelee',
#    u'buster5573',
#    u'alwayswithya',
#    u'haese-kang',
#    u'savvynoh',
#    u'insuk',
#    u'sssghsss',
#    u'memocaptain',
#    u'hyejinsung',
#    u'awsomeobig',
#    u'hyjelv1002',
#    u'dogdog',
#    u'eastgo',
#    u'skyzakard',
#    u'jongree',
#    u'95kimik',
#    u'liha',
#    u'learnerbeom',
#    u'josangil88',
#    u'downpour-ryu',
#    u'lyju7479',
#    u'sshark1124',
#    u'seokay85',
#    u'suhanjang',
#    u'kimheena',
#    u'hyulran',
#    u'fun9647',
#    u'1000ml',
#    u'dianajisunl',
#    u'mila',
#    u'jade',
#    u'brunch']},
#  u'watermsy': {u'following': [u'chyes',
#    u'homoartcus',
#    u'gunbbang',
#    u'birlzip',
#    u'savvynoh',
#    u'2kija',
#    u'kangjak',
#    u'intranet',
#    u'goodvc78',
#    u'sunsutu',
#    u'cfpajay',
#    u'captaink',
#    u'two-tone',
#    u'symriro',
#    u'hesse24',
#    u'brunch']},
#  u'webyi': {u'following': [u'goodvc78',
#    u'suyoung',
#    u'yunjungseo',
#    u'84fluxus',
#    u'elara1020',
#    u'nanta23',
#    u'yoonash',
#    u'brunchflgu',
#    u'dengine',
#    u'brunch']},
#  u'wholeman': {u'following': [u'goodvc78',
#    u'choihs0228',
#    u'eomtank',
#    u'koreajb',
#    u'groovetube',
#    u'brunchflgu',
#    u'eliotkang',
#    u'iamquadr',
#    u'promise4u',
#    u'jmh5531',
#    u'brunch']},
#  u'winter': {u'following': [u'goodvc78',
#    u'greenful',
#    u'benhyunwookim',
#    u'lifidea',
#    u'gahye',
#    u'cinehvwm',
#    u'jangnoah',
#    u'awsomeobig',
#    u'raekim',
#    u'quane',
#    u'groovetube',
#    u'oye',
#    u'sooscape',
#    u'kid',
#    u'sabumbyun',
#    u'wjchee',
#    u'bluehiker',
#    u'bwcho75',
#    u'kne',
#    u'lucidfall',
#    u'brunch6tjq',
#    u'suyoung',
#    u'sanmi',
#    u'kimyoungha',
#    u'luckyla',
#    u'kkang',
#    u'borashow',
#    u'sean',
#    u'promise4u',
#    u'lineon',
#    u'madder',
#    u'mediateam',
#    u'ghamsung',
#    u'heyum',
#    u'suhanjang',
#    u'galleryd',
#    u'piux',
#    u'heesupomkim',
#    u'kooning11',
#    u'krazyeom',
#    u'jimmyrim',
#    u'tinyhippostory',
#    u'reader76',
#    u'eastgo',
#    u'soleewogur',
#    u'dalda',
#    u'onec',
#    u'thebookman',
#    u'romanticgrey',
#    u'cysstory',
#    u'zhanghaochen',
#    u'stillalive31',
#    u'daljasee',
#    u'miretia',
#    u'sustainlife',
#    u'stopfornow',
#    u'parcchanyong',
#    u'hyvision',
#    u'flip',
#    u'yujunsang',
#    u'yellowid',
#    u'20timeline',
#    u'kimmincheol',
#    u'lookfar',
#    u'brunchywnw',
#    u'nonie1',
#    u'perytail',
#    u'alleciel',
#    u'songjh03',
#    u'yangsungmin',
#    u'brunch',
#    u'hcyoon',
#    u'lumafonto',
#    u'minam',
#    u'lonelyplanet',
#    u'pxdstory',
#    u'sein',
#    u'eugene',
#    u'brunchhxlw',
#    u'ohyjprqk',
#    u'banghaklife',
#    u'kimkwan',
#    u'minsangchoi',
#    u'ara',
#    u'jinsupark',
#    u'deleuze',
#    u'wanleehani',
#    u'greece7',
#    u'csj3814',
#    u'tina337',
#    u'storytailor',
#    u'woong0731',
#    u'yirgachefe',
#    u'jin',
#    u'brunch8m3s',
#    u'whaletreeking',
#    u'alice',
#    u'habit',
#    u'hwaada',
#    u'zazzseo',
#    u'sadrove',
#    u'luciedream',
#    u'prayise',
#    u'yeda',
#    u'marcel']},
#  u'wmkim86rmaa': {u'following': [u'goodvc78',
#    u'jungkloo',
#    u'haneulalice',
#    u'iamquadr',
#    u'cjphynmu',
#    u'promise4u',
#    u'robertlee',
#    u'osyvv',
#    u'kkonal',
#    u'suhanjang',
#    u'csj3814',
#    u'pelexus',
#    u'vijay',
#    u'hmin0606',
#    u'techhtml',
#    u'dbr',
#    u'wjchee',
#    u'jigjang',
#    u'jihoonjeong',
#    u'jimmyrim',
#    u'eunwoopark',
#    u'dengine',
#    u'lifidea',
#    u'sclplus',
#    u'brunch']},
#  u'wmzksem': {u'following': [u'brunchykx',
#    u'limelite',
#    u'goodvc78',
#    u'eejsung',
#    u'camomile',
#    u'kangjak',
#    u'sustainlife',
#    u'water-dragon',
#    u'brunch5sru',
#    u'peony',
#    u'kmin',
#    u'gunbbang',
#    u'yonghheo',
#    u'futureagent',
#    u'reeteacher',
#    u'npulen',
#    u'kotani4',
#    u'intranet',
#    u'dalda',
#    u'yudong',
#    u'taebarii',
#    u'maumdal',
#    u'rothem',
#    u'yoonash',
#    u'brunchflgu',
#    u'knockknock',
#    u'brunch']},
#  u'younghojeon': {u'following': [u'kooning11',
#    u'goodvc78',
#    u'takk',
#    u'sclplus',
#    u'lonelyplanet',
#    u'startupgemma',
#    u'editorialbe',
#    u'romanticgrey',
#    u'jnbells',
#    u'hajunho',
#    u'yoonash',
#    u'seocat',
#    u'nica0909',
#    u'valuedeveloper',
#    u'septemberfirst',
#    u'ajmind',
#    u'wjchee',
#    u'joohoonjake',
#    u'ipuris',
#    u'lyju7479',
#    u'micamica199',
#    u'promise4u',
#    u'madchick',
#    u'sapu0000',
#    u'creativety',
#    u'brunch']},
#  u'youthee': {u'following': [u'flatdesign', u'sabumbyun', u'goodvc78']},
#  u'zzubbix2': {u'following': [u'alden',
#    u'jobhelping',
#    u'goodvc78',
#    u'funder2000',
#    u'bwcho75',
#    u'hop2go',
#    u'insuk',
#    u'brunch']}}

# %% [markdown]
# ### 작가를 벡터 공간에 임베딩하기

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from matplotlib import rcParams
from datetime import datetime
import gensim, logging
import random
# %matplotlib inline  

rcParams['font.family'] = 'NanumGothic'
rcParams.update({'font.size': 14})

# %%
# word2vec으로 학습할 corpus 만들기 
corpus = []
for owner, folloings in writers_dict.items():
    #if owner != 'goodvc78':
    #    continue
    corpus = corpus + [ f['following']  for n, f in folloings.items() ]

# %%
import gensim, logging
model = gensim.models.Word2Vec(corpus, min_count=10,size=100, window=10)

# %%
for id, sim in model.most_similar(positive=['techsuda'],topn=20):
    print( "{1}   https://brunch.co.kr/@{0}".format(id, sim))
# Out:
# 0.999775469303   https://brunch.co.kr/@techhtml
# 0.999670863152   https://brunch.co.kr/@mitpiki
# 0.999667227268   https://brunch.co.kr/@wjchee
# 0.999625086784   https://brunch.co.kr/@jaeseungmun
# 0.999581456184   https://brunch.co.kr/@scottim
# 0.99956548214   https://brunch.co.kr/@amyyoungah
# 0.99955445528   https://brunch.co.kr/@soonkyujang
# 0.999521255493   https://brunch.co.kr/@joohoonjake
# 0.999487936497   https://brunch.co.kr/@msong0214
# 0.999445855618   https://brunch.co.kr/@platum
# 0.999274253845   https://brunch.co.kr/@mobizenpekr
# 0.999273777008   https://brunch.co.kr/@onefive315
# 0.999207079411   https://brunch.co.kr/@seonyu10
# 0.999095857143   https://brunch.co.kr/@brunch4nrs
# 0.999087870121   https://brunch.co.kr/@tsp
# 0.999064147472   https://brunch.co.kr/@yongjinjinipln
# 0.998956024647   https://brunch.co.kr/@haneulalice
# 0.998935103416   https://brunch.co.kr/@skpman
# 0.99872803688   https://brunch.co.kr/@manya
# 0.998719573021   https://brunch.co.kr/@banglab

# %%
## road pickle data

pkl_file = open('/Users/goodvc/Data/spot-data-analysis/resource/brunch_sns.pkl', 'rb')
writers_dict = pickle.load(pkl_file)
pkl_file.close()

# %%
# word2vec으로 학습할 corpus 만들기 
corpus = []
for owner, folloings in writers_dict.items():
    if owner != 'goodvc78':
        continue
    corpus = corpus + [ f['following']  for n, f in folloings.items() ]
