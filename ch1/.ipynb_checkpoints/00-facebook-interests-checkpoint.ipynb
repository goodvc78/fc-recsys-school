# %% [markdown]
# ## 페이스북 광고로 개인 관심사 분석
#
# # 페이스북 관심입력 문서 :  https://goo.gl/MVnmWr

# %%
# -*- coding: utf-8 -*-

import pandas as pd
import matplotlib as mpl
matplotlib.rc('font',family='AppleGothic')

# %matplotlib inline

# %% [markdown]
# ###  data load

# %%
raw_ds = pd.read_csv('/Users/goodvc/Data/fc-recsys-school/ch1/resource/facebook.csv'
                     ,index_col=0, encoding ='utf-8',skiprows=1 )
raw_ds.head()
# Out:
#          최규민  화의  베킷  위버  스타크  그레이스  맙이  소림파워
# 관심사
# 여행         1 NaN   1 NaN  NaN     1 NaN     1
# 컴퓨터서버      1 NaN   1 NaN  NaN   NaN   1   NaN
# 통계학        1 NaN NaN NaN  NaN   NaN NaN   NaN
# 가족         1 NaN NaN NaN  NaN   NaN NaN   NaN
# 검색에진최적화    1 NaN NaN NaN  NaN   NaN NaN   NaN

# %% [markdown]
# ### Nan to 0 처리

# %%
ds = raw_ds.fillna(0)
ds.head()
# Out:
#          최규민  화의  베킷  위버  스타크  그레이스  맙이  소림파워
# 관심사
# 여행         1   0   1   0    0     1   0     1
# 컴퓨터서버      1   0   1   0    0     0   1     0
# 통계학        1   0   0   0    0     0   0     0
# 가족         1   0   0   0    0     0   0     0
# 검색에진최적화    1   0   0   0    0     0   0     0

# %% [markdown]
# ### 가장 유사한 사람 찾기

# %%
## 행과 열을 바꿈
ds_T = ds.T

# %%
def cal_similarities(name, ds):
    me = ds.loc[name]
    for (target, row) in ds.iterrows():
        if target == name :
            continue
        merge = me+row
        intersections = merge[merge>1].index.values
        print u"{0}-{1} 공동 관심사({3}) = {2}".format(name, target
                            , ", ".join(intersections)
                            , len(intersections))

# %%
cal_similarities(u'베킷', ds_T)
# Out:
# 베킷-최규민 공동 관심사(4) = 여행, 컴퓨터서버, 스타트업 기업, 18세 이상
# 베킷-화의 공동 관심사(7) = 스타트업 기업, 18세 이상, 한국어, simplesite, 이민, 111miin, 음악
# 베킷-위버 공동 관심사(2) = 18세 이상, 한국어
# 베킷-스타크 공동 관심사(3) = 18세 이상, 한국어, simplesite
# 베킷-그레이스 공동 관심사(4) = 여행, 18세 이상, 한국어, simplesite
# 베킷-맙이 공동 관심사(3) = 컴퓨터서버, 스타트업 기업, 한국어
# 베킷-소림파워 공동 관심사(4) = 여행, 18세 이상, 한국어, simplesite

# %%
from scipy.spatial import distance 
from scipy import stats
import seaborn as sns
import scipy

def cos_cdist(matrix, vector, dist):
    """
    Compute the cosine distances between each row of matrix and vector.
    """
    v = vector.reshape(1, -1)
    return scipy.spatial.distance.cdist(matrix, v, 'cosine').reshape(-1)

def matrix_similarity( matrix_ds, dist='jaccard'):
    sim_mat = []
    name = []
    for idx, row in matrix_ds.iterrows():
        name.append(idx)
        sim_mat.append(cos_cdist( matrix_ds, row, dist ).tolist())
    ds = 1-pd.DataFrame(sim_mat, columns=name, index=name)
    return ds

# %% [markdown]
# ### 유사도 메트릭스를 그려보자

# %%
matrix_similarity(ds_T)
# Out:
#            최규민        화의        베킷        위버       스타크      그레이스        맙이  \
# 최규민   1.000000  0.174078  0.384900  0.087039  0.129099  0.273861  0.204124
# 화의    0.174078  1.000000  0.703526  0.272727  0.539360  0.476731  0.426401
# 베킷    0.384900  0.703526  1.000000  0.201008  0.447214  0.421637  0.235702
# 위버    0.087039  0.272727  0.201008  1.000000  0.269680  0.286039  0.213201
# 스타크   0.129099  0.539360  0.447214  0.269680  1.000000  0.565685  0.316228
# 그레이스  0.273861  0.476731  0.421637  0.286039  0.565685  1.000000  0.372678
# 맙이    0.204124  0.426401  0.235702  0.213201  0.316228  0.372678  1.000000
# 소림파워  0.182574  0.381385  0.421637  0.286039  0.565685  0.600000  0.298142
#
#           소림파워
# 최규민   0.182574
# 화의    0.381385
# 베킷    0.421637
# 위버    0.286039
# 스타크   0.565685
# 그레이스  0.600000
# 맙이    0.298142
# 소림파워  1.000000

# %% [markdown]
# ### 계층적 군집화를 해 보자

# %%
# -*- coding: utf-8 -*-
import matplotlib

tmp_ds = matrix_similarity( ds_T )

# sns.set(style="whitegrid", palette="pastel", color_codes=True,font_scale=1.2)
matplotlib.rc('font',family='AppleGothic')
matplotlib.rc('font',size=15)

cmap = sns.cubehelix_palette(as_cmap=True, rot=-.2, light=1.3)

cm = sns.clustermap(tmp_ds, cmap=cmap, linewidths=.5)

cm.fig.set_figwidth(14)
cm.fig.set_figheight(14)
